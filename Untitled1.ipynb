# %%
import spacy
nlp = spacy.load("en_core_web_sm")
import en_core_web_sm

# %%
import json
import re
from typing import TypedDict

import spacy
import structlog
from src.logger_config import configure_logger

# spaCyのモデルをロード
nlp = spacy.load("en_core_web_sm")

configure_logger()
logger = structlog.get_logger()


class SentenceInfo(TypedDict):
    text: str
    token_count: int
    chapter_number: int
    chapter_title: str
    section_number_in_chapter: int
    section_number_in_text: int
    is_chapter_title: bool


class Chapter(TypedDict):
    title: str
    number: int
    content: str


def count_tokens(sentence: str) -> int:
    """Counts the number of tokens in a sentence."""
    return len(sentence.split())


def clean_section_text(section: str) -> str:
    """Removes newline characters from a section and replaces them with spaces."""
    return section.replace("\n", " ")


def is_valid_chapter_title(text: str) -> bool:
    return text.startswith("CHAPTER") or (not text.endswith(".") and len(text) <= 20)


def extract_title_and_sections(block: str) -> tuple[str, list[str]]:
    parts = re.split(r"\n{2,}", block, 1)
    return (parts[0], parts[1:]) if len(parts) > 1 else (parts[0], [])


class TextAnalyzer:
    def __init__(self, text: str) -> None:
        self.text = text
        self.chapters: list[Chapter] = []
        self.sentences_info: list[SentenceInfo] = []
        self.current_chapter_number = 0
        self.current_section_number_in_text = 0

    def analyze_text(self) -> None:
        logger.info("Start text analysis")
        chapter_blocks = self._extract_chapter_blocks()
        self._analyze_chapter_blocks(chapter_blocks)

    def _extract_chapter_blocks(self) -> list[str]:
        return re.split(r"\n{3,}", self.text.strip())

    def _analyze_chapter_blocks(self, chapter_blocks: list[str]) -> None:
        for block in chapter_blocks:
            title, sections = extract_title_and_sections(block)
            if is_valid_chapter_title(title):
                self._increment_chapter()
                self._analyze_sections(sections, title)
            else:
                self._analyze_sections([block], "")

    def _increment_chapter(self) -> None:
        self.current_chapter_number += 1

    def _analyze_sections(self, sections: list[str], title: str) -> None:
        section_number_in_chapter = 0
        for section in sections:
            section_number_in_chapter += 1
            self._analyze_section(section, title, section_number_in_chapter)

    def _analyze_section(
        self, section: str, chapter_title: str, section_number_in_chapter: int
    ) -> None:
        cleaned_section = clean_section_text(section)
        self._process_sentences_in_section(
            cleaned_section, chapter_title, section_number_in_chapter
        )

    def _process_sentences_in_section(
        self, section: str, chapter_title: str, section_number_in_chapter: int
    ) -> None:
        doc = nlp(section)
        for sent in doc.sents:
            self._store_sentence_info(sent.text, chapter_title, section_number_in_chapter)

    def _store_sentence_info(
        self, sentence: str, chapter_title: str, section_number_in_chapter: int
    ) -> None:
        self.current_section_number_in_text += 1
        sentence_info = self._create_sentence_info(
            sentence.strip(), chapter_title, section_number_in_chapter
        )
        self.sentences_info.append(sentence_info)

    def _create_sentence_info(
        self, sentence: str, chapter_title: str, section_number_in_chapter: int
    ) -> SentenceInfo:
        token_count = count_tokens(sentence)
        return SentenceInfo(
            text=sentence,
            token_count=token_count,
            chapter_number=self.current_chapter_number,
            chapter_title=chapter_title,
            section_number_in_chapter=section_number_in_chapter,
            section_number_in_text=self.current_section_number_in_text,
            is_chapter_title=chapter_title == sentence,
        )

    def save_to_json(self, file_path: str) -> None:
        with open(file_path, "w", encoding="utf-8") as f:
            json.dump(self.sentences_info, f, ensure_ascii=False, indent=4)

# %%
file_path = "LostHorizon.txt"
with open(file_path, encoding="utf-8") as file:
    text = file.read()

analyzer = TextAnalyzer(text)
analyzer.analyze_text()
analyzer.save_to_json("analyzed_text.json")
# Out:
# 2024-02-27 07:03.19 [info     ] Start text analysis            [__main__]

# %%
analyzer.chapters
# Out:
# []

# %%
for chapter in analyzer.chapters:
    print(f"Chapter")

# %%
# !cat analyzed_text.json
# Out:
# [
#     {
#         "text": "﻿=* A Distributed Proofreaders Canada eBook *=  This ebook is made available at no cost and with very few restrictions.",
#         "token_count": 20,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 1,
#         "is_chapter_title": false
#     },
#     {
#         "text": "These restrictions apply only if (1) you make a change in the ebook (other than alteration for different display devices), or (2) you are making commercial use of the ebook.",
#         "token_count": 30,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 2,
#         "is_chapter_title": false
#     },
#     {
#         "text": "If either of these conditions applies, please contact a FP administrator before proceeding.",
#         "token_count": 13,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3,
#         "is_chapter_title": false
#     },
#     {
#         "text": "This work is in the Canadian public domain, but may be under copyright in some countries.",
#         "token_count": 16,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 4,
#         "is_chapter_title": false
#     },
#     {
#         "text": "If you live outside Canada, check your country's copyright laws.",
#         "token_count": 10,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 5,
#         "is_chapter_title": false
#     },
#     {
#         "text": "IF THE BOOK IS UNDER COPYRIGHT IN YOUR COUNTRY, DO NOT DOWNLOAD OR",
#         "token_count": 13,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 6,
#         "is_chapter_title": false
#     },
#     {
#         "text": "REDISTRIBUTE THIS FILE.",
#         "token_count": 3,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 7,
#         "is_chapter_title": false
#     },
#     {
#         "text": "_",
#         "token_count": 1,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 8,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Title:_ Lost Horizon _",
#         "token_count": 4,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 9,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Date of first publication:_ 1936 _",
#         "token_count": 6,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 10,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Author:_ James Hilton (1900-1954) _",
#         "token_count": 5,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 11,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Date first posted:_ Nov. 6, 2018 _",
#         "token_count": 7,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 12,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Date last updated:_",
#         "token_count": 3,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 13,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Nov. 6, 2018 Faded Page eBook #20181110",
#         "token_count": 7,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 14,
#         "is_chapter_title": false
#     },
#     {
#         "text": "This ebook was produced by: Al Haines, Mark Akrigg, Cindy Beyer & the online Distributed Proofreaders Canada team at http://www.pgdpcanada.net",
#         "token_count": 20,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 15,
#         "is_chapter_title": false
#     },
#     {
#         "text": "[Cover Illustration]",
#         "token_count": 2,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 16,
#         "is_chapter_title": false
#     },
#     {
#         "text": "NOVELS",
#         "token_count": 1,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 17,
#         "is_chapter_title": false
#     },
#     {
#         "text": "BY JAMES HILTON                                   ————                          AND NOW GOODBYE                          CONTANGO                          KNIGHT WITHOUT ARMOUR                          MURDER",
#         "token_count": 12,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 18,
#         "is_chapter_title": false
#     },
#     {
#         "text": "AT SCHOOL                          CATHERINE HERSELF                          THE SILVER FLAME",
#         "token_count": 7,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 19,
#         "is_chapter_title": false
#     },
#     {
#         "text": "L O S T   H O R",
#         "token_count": 7,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 20,
#         "is_chapter_title": false
#     },
#     {
#         "text": "I Z O N",
#         "token_count": 4,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 21,
#         "is_chapter_title": false
#     },
#     {
#         "text": "BY                               JAMES HILTON                       MACMILLAN  AND  CO.,  LIMITED                      ST.",
#         "token_count": 8,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 22,
#         "is_chapter_title": false
#     },
#     {
#         "text": "MARTIN'S  STREET,  LONDON                                   1936",
#         "token_count": 4,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 23,
#         "is_chapter_title": false
#     },
#     {
#         "text": "COPYRIGHT                           _First published 1933_                        _",
#         "token_count": 5,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 24,
#         "is_chapter_title": false
#     },
#     {
#         "text": "The Cottage Library 1936_",
#         "token_count": 4,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 25,
#         "is_chapter_title": false
#     },
#     {
#         "text": "PRINTED IN GREAT BRITAIN                   BY R. & R. CLARK, LIMITED, EDINBURGH",
#         "token_count": 11,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 26,
#         "is_chapter_title": false
#     },
#     {
#         "text": "PROLOGUE",
#         "token_count": 1,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 27,
#         "is_chapter_title": false
#     },
#     {
#         "text": "CIGARS had burned low, and we were beginning to sample the disillusionment that usually afflicts old school friends who meet again as men and find themselves with less in common than they used to think.",
#         "token_count": 35,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 28,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Rutherford wrote novels; Wyland was one of the Embassy secretaries; he had just given us dinner at Tempelhof—not very cheerfully, I fancied, but with the equanimity which a diplomat must always keep on tap for such occasions.",
#         "token_count": 37,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 29,
#         "is_chapter_title": false
#     },
#     {
#         "text": "It seemed likely that nothing but the fact of being three celibate Englishmen in a foreign capital could have brought us together, and I had already reached the conclusion that the slight touch of priggishness which I remembered in Wyland Tertius had not diminished with years and an M.V.O. Rutherford I liked better; he had ripened well out of the skinny, precocious infant whom I had once alternately bullied and patronised.",
#         "token_count": 71,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 30,
#         "is_chapter_title": false
#     },
#     {
#         "text": "The probability that he was making much more money and having a more interesting life than either of us, gave Wyland and me our only shared emotion—a touch of envy.",
#         "token_count": 30,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 31,
#         "is_chapter_title": false
#     },
#     {
#         "text": "The evening, however, was far from dull.",
#         "token_count": 7,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 32,
#         "is_chapter_title": false
#     },
#     {
#         "text": "We had a good view of the big Luft-Hansa machines as they arrived at the aerodrome from all parts of Central Europe, and towards dusk, when arc-flares were lighted, the scene took on a rich, theatrical brilliance.",
#         "token_count": 37,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 33,
#         "is_chapter_title": false
#     },
#     {
#         "text": "One of the planes was English, and its pilot, in full flying-kit, strolled past our table and saluted Wyland, who did not at first recognise him.",
#         "token_count": 26,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 34,
#         "is_chapter_title": false
#     },
#     {
#         "text": "When he did so there were introductions all round, and the stranger was invited to join us.",
#         "token_count": 17,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 35,
#         "is_chapter_title": false
#     },
#     {
#         "text": "He was a pleasant, jolly youth named Sanders.",
#         "token_count": 8,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 36,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Wyland made some apologetic remark about the difficulty of identifying people when they were all dressed up in Sibleys and flying-helmets; at which Sanders laughed and answered: “Oh, rather, I know that well enough.",
#         "token_count": 34,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 37,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Don’t forget I was at Baskul.”",
#         "token_count": 6,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 38,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Wyland laughed also, but less spontaneously, and the conversation then took other directions.",
#         "token_count": 13,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 39,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Sanders made an attractive addition to our small company, and we all drank a great deal of beer together.",
#         "token_count": 19,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 40,
#         "is_chapter_title": false
#     },
#     {
#         "text": "About ten o’clock Wyland left us for a moment to speak to someone at a table nearby, and Rutherford, into the sudden hiatus of talk, remarked: “Oh, by the way, you mentioned Baskul just now.",
#         "token_count": 35,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 41,
#         "is_chapter_title": false
#     },
#     {
#         "text": "I know the place slightly.",
#         "token_count": 5,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 42,
#         "is_chapter_title": false
#     },
#     {
#         "text": "What was it you were referring to that happened there?”",
#         "token_count": 10,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 43,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Sanders smiled rather shyly.",
#         "token_count": 4,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 44,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“Oh, just a bit of excitement we had once when I was in the Service.”",
#         "token_count": 15,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 45,
#         "is_chapter_title": false
#     },
#     {
#         "text": "But he was a youth who could not long refrain from being confidential.",
#         "token_count": 13,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 46,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“Fact is, an Afghan or an Afridi or somebody ran off with one of our buses, and there was the very devil to pay afterwards, as you can imagine.",
#         "token_count": 29,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 47,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Most impudent thing I ever heard of.",
#         "token_count": 7,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 48,
#         "is_chapter_title": false
#     },
#     {
#         "text": "The blighter waylaid the pilot, knocked him out, pinched his kit, and climbed into the cockpit without a soul spotting him.",
#         "token_count": 21,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 49,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Gave the mechanics the proper signals, too, and was up and away in fine style.",
#         "token_count": 15,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 50,
#         "is_chapter_title": false
#     },
#     {
#         "text": "The trouble was, he never came back.”",
#         "token_count": 7,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 51,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Rutherford looked interested.",
#         "token_count": 3,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 52,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“When did this happen?”",
#         "token_count": 4,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 53,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“Oh—must have been about a year ago.",
#         "token_count": 7,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 54,
#         "is_chapter_title": false
#     },
#     {
#         "text": "May ’thirty-one.",
#         "token_count": 2,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 55,
#         "is_chapter_title": false
#     },
#     {
#         "text": "We were evacuating civilians from Baskul to Peshawur owing to the revolution—perhaps you remember the business.",
#         "token_count": 16,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 56,
#         "is_chapter_title": false
#     },
#     {
#         "text": "The place was in a bit of an upset, or I don’t suppose the thing could have happened.",
#         "token_count": 18,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 57,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Still, it _did_ happen—and it goes some way to show that clothes make the man, doesn’t it?”",
#         "token_count": 17,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 58,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Rutherford was still interested.",
#         "token_count": 4,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 59,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“I should have thought you’d have had more than one fellow in charge of a plane on an occasion like that?”",
#         "token_count": 21,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 60,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“We did, on all the ordinary troop-carriers, but this machine was a special one, built for some maharajah originally—quite a stunt kind of outfit.",
#         "token_count": 24,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 61,
#         "is_chapter_title": false
#     },
#     {
#         "text": "The Indian Survey people had been using it for high-altitude flights in Kashmir.”",
#         "token_count": 13,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 62,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“And you say it never reached Peshawur?”  “Never reached there, and never came down anywhere else, so far as we could discover.",
#         "token_count": 22,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 63,
#         "is_chapter_title": false
#     },
#     {
#         "text": "That was the queer part about it.",
#         "token_count": 7,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 64,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Of course, if the fellow was a tribesman he might have made for the hills, thinking to hold the passengers to ransom.",
#         "token_count": 22,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 65,
#         "is_chapter_title": false
#     },
#     {
#         "text": "I suppose they all got killed, somehow.",
#         "token_count": 7,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 66,
#         "is_chapter_title": false
#     },
#     {
#         "text": "There are heaps of places on the frontier where you might crash and not be heard of afterwards.”",
#         "token_count": 18,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 67,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“Yes, I know the sort of country.",
#         "token_count": 7,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 68,
#         "is_chapter_title": false
#     },
#     {
#         "text": "How many passengers were there?”",
#         "token_count": 5,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 69,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“Four, I think.",
#         "token_count": 3,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 70,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Three men and some woman missionary.”",
#         "token_count": 6,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 71,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“Was one of the men, by any chance, named Conway?”",
#         "token_count": 10,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 72,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Sanders looked surprised.",
#         "token_count": 3,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 73,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“Why yes, as a matter of fact.",
#         "token_count": 7,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 74,
#         "is_chapter_title": false
#     },
#     {
#         "text": "‘Glory’ Conway—did you know him?”",
#         "token_count": 5,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 75,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“He and I were at the same school,” said Rutherford a little self-consciously, for it was true enough, yet a remark which he was aware did not suit him.",
#         "token_count": 29,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 76,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“He was a jolly fine chap, by all accounts of what he did at Baskul,” went on Sanders.",
#         "token_count": 18,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 77,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Rutherford nodded.",
#         "token_count": 2,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 78,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“Yes, undoubtedly . . .",
#         "token_count": 5,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 79,
#         "is_chapter_title": false
#     },
#     {
#         "text": "but how extraordinary . . .",
#         "token_count": 6,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 80,
#         "is_chapter_title": false
#     },
#     {
#         "text": "extraordinary . . .”",
#         "token_count": 4,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 81,
#         "is_chapter_title": false
#     },
#     {
#         "text": "He appeared to collect himself after a spell of mind-wandering.",
#         "token_count": 10,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 82,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Then he said: “It was never in the papers, or I think I should have read about it.",
#         "token_count": 18,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 83,
#         "is_chapter_title": false
#     },
#     {
#         "text": "How was that?”",
#         "token_count": 3,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 84,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Sanders looked suddenly rather uncomfortable, and even, I imagined, was on the point of blushing.",
#         "token_count": 15,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 85,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“To tell you the truth,” he replied, “I seem to have let out more than I should have.",
#         "token_count": 18,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 86,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Or perhaps it doesn’t matter now—it must be stale news in every mess, let alone in the bazaars.",
#         "token_count": 18,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 87,
#         "is_chapter_title": false
#     },
#     {
#         "text": "It was hushed up, you see—I mean, about the way the thing happened.",
#         "token_count": 13,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 88,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Wouldn’t have sounded well.",
#         "token_count": 4,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 89,
#         "is_chapter_title": false
#     },
#     {
#         "text": "The Government people merely gave out that one of their machines was missing, and mentioned the names.",
#         "token_count": 17,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 90,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Sort of thing that didn’t attract an awful lot of attention among outsiders.”",
#         "token_count": 13,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 91,
#         "is_chapter_title": false
#     },
#     {
#         "text": "At this point Wyland rejoined us, and Sanders turned to him half-apologetically.",
#         "token_count": 12,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 92,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“I say, Wyland, these chaps have been talking about ‘Glory’ Conway.",
#         "token_count": 11,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 93,
#         "is_chapter_title": false
#     },
#     {
#         "text": "I’m afraid I spilled the Baskul yarn—I hope you don’t think it matters?”",
#         "token_count": 13,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 94,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Wyland was severely silent for a moment.",
#         "token_count": 7,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 95,
#         "is_chapter_title": false
#     },
#     {
#         "text": "It was plain that he was reconciling the claims of compatriot courtesy and official rectitude.",
#         "token_count": 15,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 96,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“I can’t help feeling,” he said at length, “that it’s a pity to make a mere anecdote of it.",
#         "token_count": 19,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 97,
#         "is_chapter_title": false
#     },
#     {
#         "text": "I always thought you air fellows were put on your honour not to tell tales out of school.”",
#         "token_count": 18,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 98,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Having thus snubbed the youth, he turned, rather more graciously, to Rutherford.",
#         "token_count": 12,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 99,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“Of course, it’s all right in your case, but I’m sure you realise that it’s sometimes necessary for events up on the Frontier to be shrouded in a little mystery.”",
#         "token_count": 30,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 100,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“On the other hand,” replied Rutherford dryly, “one has a curious itch to know the truth.”",
#         "token_count": 16,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 101,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“It was never concealed from anyone who had any real reason for wanting to know it.",
#         "token_count": 16,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 102,
#         "is_chapter_title": false
#     },
#     {
#         "text": "I was at Peshawur at the time, and I can assure you of that.",
#         "token_count": 14,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 103,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Did you know Conway well—since school-days, I mean?”",
#         "token_count": 8,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 104,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“Just a little at Oxford, and a few chance meetings since.",
#         "token_count": 11,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 105,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Did _you_ come across him much?”",
#         "token_count": 6,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 106,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“At Angora, when I was stationed there, we met once or twice.”",
#         "token_count": 12,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 107,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“Did you like him?”",
#         "token_count": 4,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 108,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“I thought he was clever, but rather slack.”",
#         "token_count": 8,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 109,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Rutherford smiled.",
#         "token_count": 2,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 110,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“He was certainly clever.",
#         "token_count": 4,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 111,
#         "is_chapter_title": false
#     },
#     {
#         "text": "He had a most exciting university career—until war broke out.",
#         "token_count": 10,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 112,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Rowing Blue and a leading light at the Union, and prizeman for this, that, and the other—also I reckon him the best amateur pianist I ever heard.",
#         "token_count": 27,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 113,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Amazingly many-sided fellow—the kind, one feels, that Jowett would have tipped for a future premier.",
#         "token_count": 15,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 114,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Yet in point of fact, one never heard much about him after those Oxford days.",
#         "token_count": 15,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 115,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Of course the War cut into his career.",
#         "token_count": 8,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 116,
#         "is_chapter_title": false
#     },
#     {
#         "text": "He was full young",
#         "token_count": 4,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 117,
#         "is_chapter_title": false
#     },
#     {
#         "text": "and I gather he went through most of it.”",
#         "token_count": 9,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 118,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“He was blown up or something,” responded Wyland, “but nothing very serious.",
#         "token_count": 12,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 119,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Didn’t do at all badly—got a D.S.O. in France.",
#         "token_count": 9,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 120,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Then I believe he went back to Oxford for a spell—as a sort of don.",
#         "token_count": 15,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 121,
#         "is_chapter_title": false
#     },
#     {
#         "text": "I know he went East in ’twenty-one.",
#         "token_count": 7,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 122,
#         "is_chapter_title": false
#     },
#     {
#         "text": "His Oriental languages got him the job without any of the usual preliminaries.",
#         "token_count": 13,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 123,
#         "is_chapter_title": false
#     },
#     {
#         "text": "He had several posts.”",
#         "token_count": 4,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 124,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Rutherford smiled more broadly.",
#         "token_count": 4,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 125,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“Then, of course, that accounts for everything.",
#         "token_count": 7,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 126,
#         "is_chapter_title": false
#     },
#     {
#         "text": "History will never disclose the amount of sheer brilliance wasted in the routine of decoding F.O. chits and handing round tea at Legation bun-fights.”",
#         "token_count": 24,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 127,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“He was in the Consular Service, not the Diplomatic,” said Wyland loftily.",
#         "token_count": 12,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 128,
#         "is_chapter_title": false
#     },
#     {
#         "text": "It was evident that he did not care for chaff, and he made no protest when, after a little more badinage of a similar kind, Rutherford rose to go.",
#         "token_count": 29,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 129,
#         "is_chapter_title": false
#     },
#     {
#         "text": "In any case it was getting late, and I said I would go too.",
#         "token_count": 14,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 130,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Wyland’s attitude as we made our farewells was still one of official propriety suffering in silence, but Sanders was very cordial and said he hoped to meet us again sometime.",
#         "token_count": 30,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 131,
#         "is_chapter_title": false
#     },
#     {
#         "text": "I was catching a trans-continental train at a very dismal hour of the early morning, and as we waited for a taxi Rutherford asked me if I would care to spend the interval at his hotel.",
#         "token_count": 36,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 132,
#         "is_chapter_title": false
#     },
#     {
#         "text": "He had a sitting-room, he said, and we could talk.",
#         "token_count": 10,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 133,
#         "is_chapter_title": false
#     },
#     {
#         "text": "I said it would suit me excellently, and he answered: “Good.",
#         "token_count": 11,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 134,
#         "is_chapter_title": false
#     },
#     {
#         "text": "We can talk about Conway, if you like—unless you’re completely bored with his affairs.”",
#         "token_count": 14,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 135,
#         "is_chapter_title": false
#     },
#     {
#         "text": "I said that I wasn’t at all, though I had scarcely known him.",
#         "token_count": 13,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 136,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“He left at the end of my first term, and I never met him afterwards.",
#         "token_count": 15,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 137,
#         "is_chapter_title": false
#     },
#     {
#         "text": "But he was extraordinarily kind to me on one occasion—I was a new boy and there was no earthly reason why he should have done what he did.",
#         "token_count": 28,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 138,
#         "is_chapter_title": false
#     },
#     {
#         "text": "It was only a trivial thing, but I’ve always remembered it.”",
#         "token_count": 11,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 139,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Rutherford assented.",
#         "token_count": 2,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 140,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“Yes, I liked him a good deal too, though I also saw surprisingly little of him, if you measure it in time.”",
#         "token_count": 22,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 141,
#         "is_chapter_title": false
#     },
#     {
#         "text": "And then there was a somewhat odd silence, during which it was evident that we were both thinking of someone who had mattered to us far more than might have been judged from such casual contacts.",
#         "token_count": 36,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 142,
#         "is_chapter_title": false
#     },
#     {
#         "text": "I have often found since then that others who met Conway, even quite formally and for a moment, remembered him afterwards with great vividness.",
#         "token_count": 24,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 143,
#         "is_chapter_title": false
#     },
#     {
#         "text": "He was certainly remarkable as a youth, and to me, at the hero-worshipping age when I saw him, his memory is still quite romantically distinct.",
#         "token_count": 25,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 144,
#         "is_chapter_title": false
#     },
#     {
#         "text": "He was tall and extremely good-looking, and not only excelled at games but walked off with every conceivable kind of school prize.",
#         "token_count": 22,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 145,
#         "is_chapter_title": false
#     },
#     {
#         "text": "A rather sentimental headmaster once referred to his exploits as ‘glorious,’ and from that arose his nickname.",
#         "token_count": 17,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 146,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Perhaps only he could have survived it.",
#         "token_count": 7,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 147,
#         "is_chapter_title": false
#     },
#     {
#         "text": "He gave a Speech Day oration in Greek, I recollect, and was outstandingly first-rate in school theatricals.",
#         "token_count": 17,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 148,
#         "is_chapter_title": false
#     },
#     {
#         "text": "There was something rather Elizabethan about him—his casual versatility, his good looks, that effervescent combination of mental with physical activities.",
#         "token_count": 20,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 149,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Something a bit Philip-Sidneyish.",
#         "token_count": 4,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 150,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Our civilisation doesn’t so often breed people like that nowadays.",
#         "token_count": 10,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 151,
#         "is_chapter_title": false
#     },
#     {
#         "text": "I made a remark of this kind to Rutherford, and he replied: “Yes, that’s true, and we have a special word of disparagement for them—we call them dilettanti.",
#         "token_count": 28,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 152,
#         "is_chapter_title": false
#     },
#     {
#         "text": "I suppose some people must have called Conway that—people like Wyland, for instance.",
#         "token_count": 13,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 153,
#         "is_chapter_title": false
#     },
#     {
#         "text": "I don’t much care for Wyland.",
#         "token_count": 6,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 154,
#         "is_chapter_title": false
#     },
#     {
#         "text": "I can’t stand his type—all that primness and mountainous self-importance.",
#         "token_count": 10,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 155,
#         "is_chapter_title": false
#     },
#     {
#         "text": "And the complete head-prefectorial mind—did you notice it?",
#         "token_count": 8,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 156,
# ...
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3690,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Then I tried at Tatsien-Fu.",
#         "token_count": 5,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3691,
#         "is_chapter_title": false
#     },
#     {
#         "text": "It’s a weird place, a sort of world’s-end market town, deuced difficult to get at, where the Chinese coolies from Yunnan transfer their loads of tea to the Tibetans.",
#         "token_count": 29,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3692,
#         "is_chapter_title": false
#     },
#     {
#         "text": "You can read about it in my new book when it comes out.",
#         "token_count": 13,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3693,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Europeans don’t often get as far.",
#         "token_count": 6,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3694,
#         "is_chapter_title": false
#     },
#     {
#         "text": "I found the people quite civil and courteous, but there was absolutely no record of Conway’s party arriving at all.”",
#         "token_count": 20,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3695,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“So how Conway himself reached Chung-Kiang is still unexplained?”",
#         "token_count": 9,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3696,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“The only conclusion is that he wandered there, just as he might have wandered anywhere else.",
#         "token_count": 16,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3697,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Anyhow, we’re back in the realm of hard facts when we get to Chung-Kiang, that’s something.",
#         "token_count": 16,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3698,
#         "is_chapter_title": false
#     },
#     {
#         "text": "The nuns at the mission hospital were genuine enough, and so, for that matter, was Sieveking’s excitement on the ship when Conway played that pseudo-Chopin.”",
#         "token_count": 25,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3699,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Rutherford paused and then added reflectively: “It’s really an exercise in the balancing of probabilities, and I must say the scales don’t bump very emphatically either way.",
#         "token_count": 27,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3700,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Of course, if you don’t accept Conway’s story, it means that you doubt either his veracity or his sanity—one may as well be frank.”",
#         "token_count": 24,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3701,
#         "is_chapter_title": false
#     },
#     {
#         "text": "He paused again, as if inviting a comment, and I said: “As you know, I never saw him after the War, but I understand he was a good deal changed by it.”",
#         "token_count": 32,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3702,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Rutherford answered: “Yes, he certainly was, there’s no denying the fact.",
#         "token_count": 11,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3703,
#         "is_chapter_title": false
#     },
#     {
#         "text": "You can’t subject a mere boy to three years of intense physical and emotional stress without tearing something to tatters.",
#         "token_count": 20,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3704,
#         "is_chapter_title": false
#     },
#     {
#         "text": "People would say, I suppose, that he came through without a scratch.",
#         "token_count": 12,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3705,
#         "is_chapter_title": false
#     },
#     {
#         "text": "But the scratches were there—on the inside.”",
#         "token_count": 7,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3706,
#         "is_chapter_title": false
#     },
#     {
#         "text": "We talked for a little time about the War and its effects on various people, and at length he went on: “But there’s just one more point that I must mention—and perhaps in some ways the oddest of all.",
#         "token_count": 39,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3707,
#         "is_chapter_title": false
#     },
#     {
#         "text": "It came out during my enquiries at the mission.",
#         "token_count": 9,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3708,
#         "is_chapter_title": false
#     },
#     {
#         "text": "They all did their best for me there, as you can guess, but they couldn’t recollect much, especially as they’d been so busy with a fever epidemic at the time.",
#         "token_count": 30,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3709,
#         "is_chapter_title": false
#     },
#     {
#         "text": "One of the questions I put was about the manner Conway had reached the hospital first of all—whether he had presented himself alone, or had been found ill and been taken there by someone else.",
#         "token_count": 35,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3710,
#         "is_chapter_title": false
#     },
#     {
#         "text": "They couldn’t exactly remember—after all, it was a long while back—but suddenly, when I was on the point of giving up the cross-examination, one of the nuns remarked quite casually—‘I think the doctor said he was brought here by a woman.’",
#         "token_count": 41,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3711,
#         "is_chapter_title": false
#     },
#     {
#         "text": "That was all she could tell me, and as the doctor himself had left the mission, there was no confirmation to be had on the spot.",
#         "token_count": 26,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3712,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“But having got so far, I wasn’t in any mood to give up.",
#         "token_count": 13,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3713,
#         "is_chapter_title": false
#     },
#     {
#         "text": "It appeared that the doctor had gone to a bigger hospital in Shanghai, so I took the trouble to get his address and call on him there.",
#         "token_count": 27,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3714,
#         "is_chapter_title": false
#     },
#     {
#         "text": "It was just after the Jap air-raiding, and things were pretty grim.",
#         "token_count": 12,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3715,
#         "is_chapter_title": false
#     },
#     {
#         "text": "I’d met the man before during my first visit to Chung-Kiang, and he was very polite, though terribly overworked—yes, _terribly_’s the word, for, believe me, the air-raids on London by the Germans were just nothing to what the Japs did to the native parts of Shanghai.",
#         "token_count": 46,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3716,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Oh yes, he said instantly, he remembered the case of the Englishman who had lost his memory.",
#         "token_count": 17,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3717,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Was it true he had been brought to the mission hospital by a woman?",
#         "token_count": 14,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3718,
#         "is_chapter_title": false
#     },
#     {
#         "text": "I asked.",
#         "token_count": 2,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3719,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Oh yes, certainly, by a woman, a Chinese woman.",
#         "token_count": 9,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3720,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Did he remember anything about her?",
#         "token_count": 6,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3721,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Nothing, he answered, except that she had been ill of the fever herself, and had died almost immediately. . . .",
#         "token_count": 21,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3722,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Just then there was an interruption—a batch of wounded were carried in and packed on stretchers in the corridors—the wards were all full—and I didn’t care to go on taking up the man’s time, especially as the thudding of the guns at Woosung was a reminder that he would still have plenty to do.",
#         "token_count": 54,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3723,
#         "is_chapter_title": false
#     },
#     {
#         "text": "When he came back to me, looking quite cheerful even amidst such ghastliness, I just asked him one final question, and I dare say you can guess what it was.",
#         "token_count": 30,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3724,
#         "is_chapter_title": false
#     },
#     {
#         "text": "‘About that Chinese woman,’ I said.",
#         "token_count": 6,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3725,
#         "is_chapter_title": false
#     },
#     {
#         "text": "‘Was she young?’”",
#         "token_count": 3,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3726,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Rutherford flicked his cigar as if the narration had excited him quite as much as he hoped it had me.",
#         "token_count": 20,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3727,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Continuing, he said: “The little fellow looked at me solemnly for a moment, and then answered in that funny clipped English that the educated Chinese have—‘Oh no, she was most old—most old of anyone I have ever seen.’”",
#         "token_count": 38,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3728,
#         "is_chapter_title": false
#     },
#     {
#         "text": "We sat for a long time in silence, and then talked again of Conway as I remembered him, boyish and gifted and full of charm, and of the War that had altered him, and of so many mysteries of time and age and of the mind, and of the little Manchu who had been ‘most old,’ and of the strange ultimate dream of Blue Moon.",
#         "token_count": 65,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3729,
#         "is_chapter_title": false
#     },
#     {
#         "text": "“Do you think he will ever find it?”",
#         "token_count": 8,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3730,
#         "is_chapter_title": false
#     },
#     {
#         "text": "I asked.",
#         "token_count": 2,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3731,
#         "is_chapter_title": false
#     },
#     {
#         "text": "WOODFORD GREEN   April 1933                                 THE END    _",
#         "token_count": 7,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3732,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Printed in Great Britain by_ R. & R. CLARK, LIMITED, _Edinburgh_.",
#         "token_count": 11,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3733,
#         "is_chapter_title": false
#     },
#     {
#         "text": "TRANSCRIBER NOTES  Misspelled words and printer errors have been corrected.",
#         "token_count": 10,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3734,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Where multiple spellings occur, majority use has been employed.",
#         "token_count": 9,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3735,
#         "is_chapter_title": false
#     },
#     {
#         "text": "Punctuation has been maintained except where obvious printer errors occur.",
#         "token_count": 10,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3736,
#         "is_chapter_title": false
#     },
#     {
#         "text": "[The end of _Lost Horizon_ by James Hilton]",
#         "token_count": 8,
#         "chapter_number": 0,
#         "chapter_title": "",
#         "section_number_in_chapter": 1,
#         "section_number_in_text": 3737,
#         "is_chapter_title": false
#     }
# ]

# %%
analyzer.sentences_info
# Out:
# [{'text': '\ufeff=* A Distributed Proofreaders Canada eBook *=  This ebook is made available at no cost and with very few restrictions.',
#   'token_count': 20,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 1,
#   'is_chapter_title': False},
#  {'text': 'These restrictions apply only if (1) you make a change in the ebook (other than alteration for different display devices), or (2) you are making commercial use of the ebook.',
#   'token_count': 30,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 2,
#   'is_chapter_title': False},
#  {'text': 'If either of these conditions applies, please contact a FP administrator before proceeding.',
#   'token_count': 13,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 3,
#   'is_chapter_title': False},
#  {'text': 'This work is in the Canadian public domain, but may be under copyright in some countries.',
#   'token_count': 16,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 4,
#   'is_chapter_title': False},
#  {'text': "If you live outside Canada, check your country's copyright laws.",
#   'token_count': 10,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 5,
#   'is_chapter_title': False},
#  {'text': 'IF THE BOOK IS UNDER COPYRIGHT IN YOUR COUNTRY, DO NOT DOWNLOAD OR',
#   'token_count': 13,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 6,
#   'is_chapter_title': False},
#  {'text': 'REDISTRIBUTE THIS FILE.',
#   'token_count': 3,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 7,
#   'is_chapter_title': False},
#  {'text': '_',
#   'token_count': 1,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 8,
#   'is_chapter_title': False},
#  {'text': 'Title:_ Lost Horizon _',
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 9,
#   'is_chapter_title': False},
#  {'text': 'Date of first publication:_ 1936 _',
#   'token_count': 6,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 10,
#   'is_chapter_title': False},
#  {'text': 'Author:_ James Hilton (1900-1954) _',
#   'token_count': 5,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 11,
#   'is_chapter_title': False},
#  {'text': 'Date first posted:_ Nov. 6, 2018 _',
#   'token_count': 7,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 12,
#   'is_chapter_title': False},
#  {'text': 'Date last updated:_',
#   'token_count': 3,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 13,
#   'is_chapter_title': False},
#  {'text': 'Nov. 6, 2018 Faded Page eBook #20181110',
#   'token_count': 7,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 14,
#   'is_chapter_title': False},
#  {'text': 'This ebook was produced by: Al Haines, Mark Akrigg, Cindy Beyer & the online Distributed Proofreaders Canada team at http://www.pgdpcanada.net',
#   'token_count': 20,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 15,
#   'is_chapter_title': False},
#  {'text': '[Cover Illustration]',
#   'token_count': 2,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 16,
#   'is_chapter_title': False},
#  {'text': 'NOVELS',
#   'token_count': 1,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 17,
#   'is_chapter_title': False},
#  {'text': 'BY JAMES HILTON                                   ————                          AND NOW GOODBYE                          CONTANGO                          KNIGHT WITHOUT ARMOUR                          MURDER',
#   'token_count': 12,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 18,
#   'is_chapter_title': False},
#  {'text': 'AT SCHOOL                          CATHERINE HERSELF                          THE SILVER FLAME',
#   'token_count': 7,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 19,
#   'is_chapter_title': False},
#  {'text': 'L O S T   H O R',
#   'token_count': 7,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 20,
#   'is_chapter_title': False},
#  {'text': 'I Z O N',
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 21,
#   'is_chapter_title': False},
#  {'text': 'BY                               JAMES HILTON                       MACMILLAN  AND  CO.,  LIMITED                      ST.',
#   'token_count': 8,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 22,
#   'is_chapter_title': False},
#  {'text': "MARTIN'S  STREET,  LONDON                                   1936",
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 23,
#   'is_chapter_title': False},
#  {'text': 'COPYRIGHT                           _First published 1933_                        _',
#   'token_count': 5,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 24,
#   'is_chapter_title': False},
#  {'text': 'The Cottage Library 1936_',
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 25,
#   'is_chapter_title': False},
#  {'text': 'PRINTED IN GREAT BRITAIN                   BY R. & R. CLARK, LIMITED, EDINBURGH',
#   'token_count': 11,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 26,
#   'is_chapter_title': False},
#  {'text': 'PROLOGUE',
#   'token_count': 1,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 27,
#   'is_chapter_title': False},
#  {'text': 'CIGARS had burned low, and we were beginning to sample the disillusionment that usually afflicts old school friends who meet again as men and find themselves with less in common than they used to think.',
#   'token_count': 35,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 28,
#   'is_chapter_title': False},
#  {'text': 'Rutherford wrote novels; Wyland was one of the Embassy secretaries; he had just given us dinner at Tempelhof—not very cheerfully, I fancied, but with the equanimity which a diplomat must always keep on tap for such occasions.',
#   'token_count': 37,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 29,
#   'is_chapter_title': False},
#  {'text': 'It seemed likely that nothing but the fact of being three celibate Englishmen in a foreign capital could have brought us together, and I had already reached the conclusion that the slight touch of priggishness which I remembered in Wyland Tertius had not diminished with years and an M.V.O. Rutherford I liked better; he had ripened well out of the skinny, precocious infant whom I had once alternately bullied and patronised.',
#   'token_count': 71,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 30,
#   'is_chapter_title': False},
#  {'text': 'The probability that he was making much more money and having a more interesting life than either of us, gave Wyland and me our only shared emotion—a touch of envy.',
#   'token_count': 30,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 31,
#   'is_chapter_title': False},
#  {'text': 'The evening, however, was far from dull.',
#   'token_count': 7,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 32,
#   'is_chapter_title': False},
#  {'text': 'We had a good view of the big Luft-Hansa machines as they arrived at the aerodrome from all parts of Central Europe, and towards dusk, when arc-flares were lighted, the scene took on a rich, theatrical brilliance.',
#   'token_count': 37,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 33,
#   'is_chapter_title': False},
#  {'text': 'One of the planes was English, and its pilot, in full flying-kit, strolled past our table and saluted Wyland, who did not at first recognise him.',
#   'token_count': 26,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 34,
#   'is_chapter_title': False},
#  {'text': 'When he did so there were introductions all round, and the stranger was invited to join us.',
#   'token_count': 17,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 35,
#   'is_chapter_title': False},
#  {'text': 'He was a pleasant, jolly youth named Sanders.',
#   'token_count': 8,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 36,
#   'is_chapter_title': False},
#  {'text': 'Wyland made some apologetic remark about the difficulty of identifying people when they were all dressed up in Sibleys and flying-helmets; at which Sanders laughed and answered: “Oh, rather, I know that well enough.',
#   'token_count': 34,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 37,
#   'is_chapter_title': False},
#  {'text': 'Don’t forget I was at Baskul.”',
#   'token_count': 6,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 38,
#   'is_chapter_title': False},
#  {'text': 'Wyland laughed also, but less spontaneously, and the conversation then took other directions.',
#   'token_count': 13,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 39,
#   'is_chapter_title': False},
#  {'text': 'Sanders made an attractive addition to our small company, and we all drank a great deal of beer together.',
#   'token_count': 19,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 40,
#   'is_chapter_title': False},
#  {'text': 'About ten o’clock Wyland left us for a moment to speak to someone at a table nearby, and Rutherford, into the sudden hiatus of talk, remarked: “Oh, by the way, you mentioned Baskul just now.',
#   'token_count': 35,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 41,
#   'is_chapter_title': False},
#  {'text': 'I know the place slightly.',
#   'token_count': 5,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 42,
#   'is_chapter_title': False},
#  {'text': 'What was it you were referring to that happened there?”',
#   'token_count': 10,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 43,
#   'is_chapter_title': False},
#  {'text': 'Sanders smiled rather shyly.',
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 44,
#   'is_chapter_title': False},
#  {'text': '“Oh, just a bit of excitement we had once when I was in the Service.”',
#   'token_count': 15,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 45,
#   'is_chapter_title': False},
#  {'text': 'But he was a youth who could not long refrain from being confidential.',
#   'token_count': 13,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 46,
#   'is_chapter_title': False},
#  {'text': '“Fact is, an Afghan or an Afridi or somebody ran off with one of our buses, and there was the very devil to pay afterwards, as you can imagine.',
#   'token_count': 29,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 47,
#   'is_chapter_title': False},
#  {'text': 'Most impudent thing I ever heard of.',
#   'token_count': 7,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 48,
#   'is_chapter_title': False},
#  {'text': 'The blighter waylaid the pilot, knocked him out, pinched his kit, and climbed into the cockpit without a soul spotting him.',
#   'token_count': 21,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 49,
#   'is_chapter_title': False},
#  {'text': 'Gave the mechanics the proper signals, too, and was up and away in fine style.',
#   'token_count': 15,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 50,
#   'is_chapter_title': False},
#  {'text': 'The trouble was, he never came back.”',
#   'token_count': 7,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 51,
#   'is_chapter_title': False},
#  {'text': 'Rutherford looked interested.',
#   'token_count': 3,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 52,
#   'is_chapter_title': False},
#  {'text': '“When did this happen?”',
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 53,
#   'is_chapter_title': False},
#  {'text': '“Oh—must have been about a year ago.',
#   'token_count': 7,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 54,
#   'is_chapter_title': False},
#  {'text': 'May ’thirty-one.',
#   'token_count': 2,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 55,
#   'is_chapter_title': False},
#  {'text': 'We were evacuating civilians from Baskul to Peshawur owing to the revolution—perhaps you remember the business.',
#   'token_count': 16,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 56,
#   'is_chapter_title': False},
#  {'text': 'The place was in a bit of an upset, or I don’t suppose the thing could have happened.',
#   'token_count': 18,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 57,
#   'is_chapter_title': False},
#  {'text': 'Still, it _did_ happen—and it goes some way to show that clothes make the man, doesn’t it?”',
#   'token_count': 17,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 58,
#   'is_chapter_title': False},
#  {'text': 'Rutherford was still interested.',
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 59,
#   'is_chapter_title': False},
#  {'text': '“I should have thought you’d have had more than one fellow in charge of a plane on an occasion like that?”',
#   'token_count': 21,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 60,
#   'is_chapter_title': False},
#  {'text': '“We did, on all the ordinary troop-carriers, but this machine was a special one, built for some maharajah originally—quite a stunt kind of outfit.',
#   'token_count': 24,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 61,
#   'is_chapter_title': False},
#  {'text': 'The Indian Survey people had been using it for high-altitude flights in Kashmir.”',
#   'token_count': 13,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 62,
#   'is_chapter_title': False},
#  {'text': '“And you say it never reached Peshawur?”  “Never reached there, and never came down anywhere else, so far as we could discover.',
#   'token_count': 22,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 63,
#   'is_chapter_title': False},
#  {'text': 'That was the queer part about it.',
#   'token_count': 7,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 64,
#   'is_chapter_title': False},
#  {'text': 'Of course, if the fellow was a tribesman he might have made for the hills, thinking to hold the passengers to ransom.',
#   'token_count': 22,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 65,
#   'is_chapter_title': False},
#  {'text': 'I suppose they all got killed, somehow.',
#   'token_count': 7,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 66,
#   'is_chapter_title': False},
#  {'text': 'There are heaps of places on the frontier where you might crash and not be heard of afterwards.”',
#   'token_count': 18,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 67,
#   'is_chapter_title': False},
#  {'text': '“Yes, I know the sort of country.',
#   'token_count': 7,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 68,
#   'is_chapter_title': False},
#  {'text': 'How many passengers were there?”',
#   'token_count': 5,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 69,
#   'is_chapter_title': False},
#  {'text': '“Four, I think.',
#   'token_count': 3,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 70,
#   'is_chapter_title': False},
#  {'text': 'Three men and some woman missionary.”',
#   'token_count': 6,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 71,
#   'is_chapter_title': False},
#  {'text': '“Was one of the men, by any chance, named Conway?”',
#   'token_count': 10,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 72,
#   'is_chapter_title': False},
#  {'text': 'Sanders looked surprised.',
#   'token_count': 3,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 73,
#   'is_chapter_title': False},
#  {'text': '“Why yes, as a matter of fact.',
#   'token_count': 7,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 74,
#   'is_chapter_title': False},
#  {'text': '‘Glory’ Conway—did you know him?”',
#   'token_count': 5,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 75,
#   'is_chapter_title': False},
#  {'text': '“He and I were at the same school,” said Rutherford a little self-consciously, for it was true enough, yet a remark which he was aware did not suit him.',
#   'token_count': 29,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 76,
#   'is_chapter_title': False},
#  {'text': '“He was a jolly fine chap, by all accounts of what he did at Baskul,” went on Sanders.',
#   'token_count': 18,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 77,
#   'is_chapter_title': False},
#  {'text': 'Rutherford nodded.',
#   'token_count': 2,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 78,
#   'is_chapter_title': False},
#  {'text': '“Yes, undoubtedly . . .',
#   'token_count': 5,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 79,
#   'is_chapter_title': False},
#  {'text': 'but how extraordinary . . .',
#   'token_count': 6,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 80,
#   'is_chapter_title': False},
#  {'text': 'extraordinary . . .”',
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 81,
#   'is_chapter_title': False},
#  {'text': 'He appeared to collect himself after a spell of mind-wandering.',
#   'token_count': 10,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 82,
#   'is_chapter_title': False},
#  {'text': 'Then he said: “It was never in the papers, or I think I should have read about it.',
#   'token_count': 18,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 83,
#   'is_chapter_title': False},
#  {'text': 'How was that?”',
#   'token_count': 3,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 84,
#   'is_chapter_title': False},
#  {'text': 'Sanders looked suddenly rather uncomfortable, and even, I imagined, was on the point of blushing.',
#   'token_count': 15,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 85,
#   'is_chapter_title': False},
#  {'text': '“To tell you the truth,” he replied, “I seem to have let out more than I should have.',
#   'token_count': 18,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 86,
#   'is_chapter_title': False},
#  {'text': 'Or perhaps it doesn’t matter now—it must be stale news in every mess, let alone in the bazaars.',
#   'token_count': 18,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 87,
#   'is_chapter_title': False},
#  {'text': 'It was hushed up, you see—I mean, about the way the thing happened.',
#   'token_count': 13,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 88,
#   'is_chapter_title': False},
#  {'text': 'Wouldn’t have sounded well.',
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 89,
#   'is_chapter_title': False},
#  {'text': 'The Government people merely gave out that one of their machines was missing, and mentioned the names.',
#   'token_count': 17,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 90,
#   'is_chapter_title': False},
#  {'text': 'Sort of thing that didn’t attract an awful lot of attention among outsiders.”',
#   'token_count': 13,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 91,
#   'is_chapter_title': False},
#  {'text': 'At this point Wyland rejoined us, and Sanders turned to him half-apologetically.',
#   'token_count': 12,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 92,
#   'is_chapter_title': False},
#  {'text': '“I say, Wyland, these chaps have been talking about ‘Glory’ Conway.',
#   'token_count': 11,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 93,
#   'is_chapter_title': False},
#  {'text': 'I’m afraid I spilled the Baskul yarn—I hope you don’t think it matters?”',
#   'token_count': 13,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 94,
#   'is_chapter_title': False},
#  {'text': 'Wyland was severely silent for a moment.',
#   'token_count': 7,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 95,
#   'is_chapter_title': False},
#  {'text': 'It was plain that he was reconciling the claims of compatriot courtesy and official rectitude.',
#   'token_count': 15,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 96,
#   'is_chapter_title': False},
#  {'text': '“I can’t help feeling,” he said at length, “that it’s a pity to make a mere anecdote of it.',
#   'token_count': 19,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 97,
#   'is_chapter_title': False},
#  {'text': 'I always thought you air fellows were put on your honour not to tell tales out of school.”',
#   'token_count': 18,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 98,
#   'is_chapter_title': False},
#  {'text': 'Having thus snubbed the youth, he turned, rather more graciously, to Rutherford.',
#   'token_count': 12,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 99,
#   'is_chapter_title': False},
#  {'text': '“Of course, it’s all right in your case, but I’m sure you realise that it’s sometimes necessary for events up on the Frontier to be shrouded in a little mystery.”',
#   'token_count': 30,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 100,
#   'is_chapter_title': False},
#  {'text': '“On the other hand,” replied Rutherford dryly, “one has a curious itch to know the truth.”',
#   'token_count': 16,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 101,
#   'is_chapter_title': False},
#  {'text': '“It was never concealed from anyone who had any real reason for wanting to know it.',
#   'token_count': 16,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 102,
#   'is_chapter_title': False},
#  {'text': 'I was at Peshawur at the time, and I can assure you of that.',
#   'token_count': 14,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 103,
#   'is_chapter_title': False},
#  {'text': 'Did you know Conway well—since school-days, I mean?”',
#   'token_count': 8,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 104,
#   'is_chapter_title': False},
#  {'text': '“Just a little at Oxford, and a few chance meetings since.',
#   'token_count': 11,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 105,
#   'is_chapter_title': False},
#  {'text': 'Did _you_ come across him much?”',
#   'token_count': 6,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 106,
#   'is_chapter_title': False},
#  {'text': '“At Angora, when I was stationed there, we met once or twice.”',
#   'token_count': 12,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 107,
#   'is_chapter_title': False},
#  {'text': '“Did you like him?”',
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 108,
#   'is_chapter_title': False},
#  {'text': '“I thought he was clever, but rather slack.”',
#   'token_count': 8,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 109,
#   'is_chapter_title': False},
#  {'text': 'Rutherford smiled.',
#   'token_count': 2,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 110,
#   'is_chapter_title': False},
#  {'text': '“He was certainly clever.',
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 111,
#   'is_chapter_title': False},
#  {'text': 'He had a most exciting university career—until war broke out.',
#   'token_count': 10,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 112,
#   'is_chapter_title': False},
#  {'text': 'Rowing Blue and a leading light at the Union, and prizeman for this, that, and the other—also I reckon him the best amateur pianist I ever heard.',
#   'token_count': 27,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 113,
#   'is_chapter_title': False},
#  {'text': 'Amazingly many-sided fellow—the kind, one feels, that Jowett would have tipped for a future premier.',
#   'token_count': 15,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 114,
#   'is_chapter_title': False},
#  {'text': 'Yet in point of fact, one never heard much about him after those Oxford days.',
#   'token_count': 15,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 115,
#   'is_chapter_title': False},
#  {'text': 'Of course the War cut into his career.',
#   'token_count': 8,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 116,
#   'is_chapter_title': False},
#  {'text': 'He was full young',
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 117,
#   'is_chapter_title': False},
#  {'text': 'and I gather he went through most of it.”',
#   'token_count': 9,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 118,
#   'is_chapter_title': False},
#  {'text': '“He was blown up or something,” responded Wyland, “but nothing very serious.',
#   'token_count': 12,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 119,
#   'is_chapter_title': False},
#  {'text': 'Didn’t do at all badly—got a D.S.O. in France.',
#   'token_count': 9,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 120,
#   'is_chapter_title': False},
#  {'text': 'Then I believe he went back to Oxford for a spell—as a sort of don.',
#   'token_count': 15,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 121,
#   'is_chapter_title': False},
#  {'text': 'I know he went East in ’twenty-one.',
#   'token_count': 7,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 122,
#   'is_chapter_title': False},
#  {'text': 'His Oriental languages got him the job without any of the usual preliminaries.',
#   'token_count': 13,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 123,
#   'is_chapter_title': False},
#  {'text': 'He had several posts.”',
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 124,
#   'is_chapter_title': False},
#  {'text': 'Rutherford smiled more broadly.',
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 125,
#   'is_chapter_title': False},
#  {'text': '“Then, of course, that accounts for everything.',
#   'token_count': 7,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 126,
#   'is_chapter_title': False},
#  {'text': 'History will never disclose the amount of sheer brilliance wasted in the routine of decoding F.O. chits and handing round tea at Legation bun-fights.”',
#   'token_count': 24,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 127,
#   'is_chapter_title': False},
#  {'text': '“He was in the Consular Service, not the Diplomatic,” said Wyland loftily.',
#   'token_count': 12,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 128,
#   'is_chapter_title': False},
#  {'text': 'It was evident that he did not care for chaff, and he made no protest when, after a little more badinage of a similar kind, Rutherford rose to go.',
#   'token_count': 29,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 129,
#   'is_chapter_title': False},
#  {'text': 'In any case it was getting late, and I said I would go too.',
#   'token_count': 14,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 130,
#   'is_chapter_title': False},
#  {'text': 'Wyland’s attitude as we made our farewells was still one of official propriety suffering in silence, but Sanders was very cordial and said he hoped to meet us again sometime.',
#   'token_count': 30,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 131,
#   'is_chapter_title': False},
#  {'text': 'I was catching a trans-continental train at a very dismal hour of the early morning, and as we waited for a taxi Rutherford asked me if I would care to spend the interval at his hotel.',
#   'token_count': 36,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 132,
#   'is_chapter_title': False},
#  {'text': 'He had a sitting-room, he said, and we could talk.',
#   'token_count': 10,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 133,
#   'is_chapter_title': False},
#  {'text': 'I said it would suit me excellently, and he answered: “Good.',
#   'token_count': 11,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 134,
#   'is_chapter_title': False},
#  {'text': 'We can talk about Conway, if you like—unless you’re completely bored with his affairs.”',
#   'token_count': 14,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 135,
#   'is_chapter_title': False},
#  {'text': 'I said that I wasn’t at all, though I had scarcely known him.',
#   'token_count': 13,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 136,
#   'is_chapter_title': False},
#  {'text': '“He left at the end of my first term, and I never met him afterwards.',
#   'token_count': 15,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 137,
#   'is_chapter_title': False},
#  {'text': 'But he was extraordinarily kind to me on one occasion—I was a new boy and there was no earthly reason why he should have done what he did.',
#   'token_count': 28,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 138,
#   'is_chapter_title': False},
#  {'text': 'It was only a trivial thing, but I’ve always remembered it.”',
#   'token_count': 11,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 139,
#   'is_chapter_title': False},
#  {'text': 'Rutherford assented.',
#   'token_count': 2,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 140,
#   'is_chapter_title': False},
#  {'text': '“Yes, I liked him a good deal too, though I also saw surprisingly little of him, if you measure it in time.”',
#   'token_count': 22,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 141,
#   'is_chapter_title': False},
#  {'text': 'And then there was a somewhat odd silence, during which it was evident that we were both thinking of someone who had mattered to us far more than might have been judged from such casual contacts.',
#   'token_count': 36,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 142,
#   'is_chapter_title': False},
#  {'text': 'I have often found since then that others who met Conway, even quite formally and for a moment, remembered him afterwards with great vividness.',
#   'token_count': 24,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 143,
#   'is_chapter_title': False},
#  {'text': 'He was certainly remarkable as a youth, and to me, at the hero-worshipping age when I saw him, his memory is still quite romantically distinct.',
#   'token_count': 25,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 144,
#   'is_chapter_title': False},
#  {'text': 'He was tall and extremely good-looking, and not only excelled at games but walked off with every conceivable kind of school prize.',
#   'token_count': 22,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 145,
#   'is_chapter_title': False},
#  {'text': 'A rather sentimental headmaster once referred to his exploits as ‘glorious,’ and from that arose his nickname.',
#   'token_count': 17,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 146,
#   'is_chapter_title': False},
#  {'text': 'Perhaps only he could have survived it.',
#   'token_count': 7,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 147,
#   'is_chapter_title': False},
#  {'text': 'He gave a Speech Day oration in Greek, I recollect, and was outstandingly first-rate in school theatricals.',
#   'token_count': 17,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 148,
#   'is_chapter_title': False},
#  {'text': 'There was something rather Elizabethan about him—his casual versatility, his good looks, that effervescent combination of mental with physical activities.',
#   'token_count': 20,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 149,
#   'is_chapter_title': False},
#  {'text': 'Something a bit Philip-Sidneyish.',
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 150,
#   'is_chapter_title': False},
#  {'text': 'Our civilisation doesn’t so often breed people like that nowadays.',
#   'token_count': 10,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 151,
#   'is_chapter_title': False},
#  {'text': 'I made a remark of this kind to Rutherford, and he replied: “Yes, that’s true, and we have a special word of disparagement for them—we call them dilettanti.',
#   'token_count': 28,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 152,
#   'is_chapter_title': False},
#  {'text': 'I suppose some people must have called Conway that—people like Wyland, for instance.',
#   'token_count': 13,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 153,
#   'is_chapter_title': False},
#  {'text': 'I don’t much care for Wyland.',
#   'token_count': 6,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 154,
#   'is_chapter_title': False},
#  {'text': 'I can’t stand his type—all that primness and mountainous self-importance.',
#   'token_count': 10,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 155,
#   'is_chapter_title': False},
#  {'text': 'And the complete head-prefectorial mind—did you notice it?',
#   'token_count': 8,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 156,
#   'is_chapter_title': False},
#  {'text': 'Little phrases about ‘putting people on their honour’ and ‘telling tales out of school’—as if the bally Empire was the Fifth Form at St. Dominic’s!',
#   'token_count': 25,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 157,
#   'is_chapter_title': False},
#  {'text': 'But then I always fall foul of these sahib diplomats.”',
#   'token_count': 10,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 158,
#   'is_chapter_title': False},
#  {'text': 'We drove on a few streets in silence, and then he continued: “Still, I wouldn’t have missed this evening.',
#   'token_count': 19,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 159,
#   'is_chapter_title': False},
#  {'text': 'It was a peculiar experience for me, hearing Sanders tell that story about the affair at Baskul.',
#   'token_count': 17,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 160,
#   'is_chapter_title': False},
#  {'text': 'You see, I’d heard it before, and hadn’t properly believed it.',
#   'token_count': 11,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 161,
#   'is_chapter_title': False},
#  {'text': 'It was part of a much more fantastic story, which I saw no reason to believe at all—or well, only one very slight reason, anyway.',
#   'token_count': 25,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 162,
#   'is_chapter_title': False},
#  {'text': '_',
#   'token_count': 1,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 163,
#   'is_chapter_title': False},
#  {'text': 'Now_ there are _two_ very slight reasons.',
#   'token_count': 7,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 164,
#   'is_chapter_title': False},
#  {'text': 'I dare say you can guess that I’m not a particularly gullible person.',
#   'token_count': 13,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 165,
#   'is_chapter_title': False},
#  {'text': 'I’ve spent a good deal of my life travelling about, and I know there are queer things in the world—if you see them yourself, that is, but not so often if you hear of them second-hand.',
#   'token_count': 36,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 166,
#   'is_chapter_title': False},
#  {'text': 'And yet . . .”',
#   'token_count': 5,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 167,
#   'is_chapter_title': False},
#  {'text': 'He seemed suddenly to realise that what he was saying could not mean very much to me, and broke off with a laugh.',
#   'token_count': 23,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 168,
#   'is_chapter_title': False},
#  {'text': '“Well, there’s one thing certain—I’m not likely to take Wyland into my confidence.',
#   'token_count': 13,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 169,
#   'is_chapter_title': False},
#  {'text': 'It would be like trying to sell an epic poem to _Tit-Bits_.',
#   'token_count': 12,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 170,
#   'is_chapter_title': False},
#  {'text': 'I’d rather try my luck with you.”',
#   'token_count': 7,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 171,
#   'is_chapter_title': False},
#  {'text': '“Perhaps you flatter me,” I suggested.',
#   'token_count': 6,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 172,
#   'is_chapter_title': False},
#  {'text': '“Your book doesn’t lead me to think so.”',
#   'token_count': 8,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 173,
#   'is_chapter_title': False},
#  {'text': 'I had not mentioned my authorship of that rather technical work (after all, a neurologist’s is not everybody’s ‘shop’), and I was agreeably surprised that Rutherford had even heard about it.',
#   'token_count': 31,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 174,
#   'is_chapter_title': False},
#  {'text': 'I said as much, and he answered: “Well, you see, I was interested, because amnesia was Conway’s trouble—at one time.”',
#   'token_count': 20,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 175,
#   'is_chapter_title': False},
#  {'text': 'We had reached the hotel and he had to get his key at the bureau.',
#   'token_count': 15,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 176,
#   'is_chapter_title': False},
#  {'text': 'As we went up to the fifth floor he said: “All this is mere beating about the bush.',
#   'token_count': 18,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 177,
#   'is_chapter_title': False},
#  {'text': 'The fact is, Conway isn’t dead.',
#   'token_count': 6,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 178,
#   'is_chapter_title': False},
#  {'text': 'At least he wasn’t a few months ago.”',
#   'token_count': 8,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 179,
#   'is_chapter_title': False},
#  {'text': 'This seemed beyond comment in the narrow space and time of a lift-ascent.',
#   'token_count': 13,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 180,
#   'is_chapter_title': False},
#  {'text': 'In the corridor a few seconds later I answered: “Are you sure of that?',
#   'token_count': 14,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 181,
#   'is_chapter_title': False},
#  {'text': 'How do you know?”',
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 182,
#   'is_chapter_title': False},
#  {'text': 'And he responded, unlocking his door: “Because I travelled with him from Shanghai to Honolulu in a Jap liner last November.”',
#   'token_count': 21,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 183,
#   'is_chapter_title': False},
#  {'text': 'He did not speak again till we were settled in armchairs and had fixed ourselves with drinks and cigars.',
#   'token_count': 19,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 184,
#   'is_chapter_title': False},
#  {'text': '“You see, I was in China in the autumn—on a holiday.',
#   'token_count': 11,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 185,
#   'is_chapter_title': False},
#  {'text': 'I’m always wandering about.',
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 186,
#   'is_chapter_title': False},
#  {'text': 'I hadn’t seen Conway for years—we never corresponded, and I can’t say he was often in my thoughts, though his was one of the few faces that have always come to me quite effortlessly if I tried to picture them.',
#   'token_count': 40,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 187,
#   'is_chapter_title': False},
#  {'text': 'I had been visiting a friend in Hankow and was returning by the Pekin express.',
#   'token_count': 15,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 188,
#   'is_chapter_title': False},
# ...
#   'section_number_in_text': 940,
#   'is_chapter_title': False},
#  {'text': 'Conway could not imagine where they were all going, but it certainly seemed providential, as Miss Brinklow had said, that such a detachment should chance to be passing just there and then.',
#   'token_count': 32,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 941,
#   'is_chapter_title': False},
#  {'text': 'As soon as he was within hailing distance he left his own party and walked ahead, though not hurriedly, for he knew that Orientals enjoy the ritual of meeting and like to take their time over it.',
#   'token_count': 37,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 942,
#   'is_chapter_title': False},
#  {'text': 'Halting when a few yards off, he bowed with due courtesy.',
#   'token_count': 11,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 943,
#   'is_chapter_title': False},
#  {'text': 'Much to his surprise the robed figure stepped from the chair, came forward with dignified deliberation, and held out his hand.',
#   'token_count': 21,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 944,
#   'is_chapter_title': False},
#  {'text': 'Conway responded, and observed an old or elderly Chinese, grey-haired, clean-shaven, and rather pallidly decorative in a silk embroidered gown.',
#   'token_count': 20,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 945,
#   'is_chapter_title': False},
#  {'text': 'He in his turn appeared to be submitting Conway to the same kind of ready reckoning.',
#   'token_count': 16,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 946,
#   'is_chapter_title': False},
#  {'text': 'Then, in precise and perhaps too accurate English, he said: “I am from the lamasery of Shangri-La.”  Conway bowed again, and after a suitable pause began to explain briefly the circumstances that had brought him and his three companions to such an unfrequented part of the world.',
#   'token_count': 47,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 947,
#   'is_chapter_title': False},
#  {'text': 'At the end of the recital the Chinese made a gesture of understanding.',
#   'token_count': 13,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 948,
#   'is_chapter_title': False},
#  {'text': '“It is indeed remarkable,” he said, and gazed reflectively at the damaged aeroplane.',
#   'token_count': 13,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 949,
#   'is_chapter_title': False},
#  {'text': 'Then he added: “My name is Chang, if you would be so good as to present me to your friends.”',
#   'token_count': 20,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 950,
#   'is_chapter_title': False},
#  {'text': 'Conway managed to smile urbanely.',
#   'token_count': 5,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 951,
#   'is_chapter_title': False},
#  {'text': 'He was rather taken with this latest phenomenon—a Chinese who spoke perfect English and observed the social formalities of Bond Street amidst the wilds of Tibet.',
#   'token_count': 26,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 952,
#   'is_chapter_title': False},
#  {'text': 'He turned to the others, who had by this time caught up and were regarding the encounter with varying degrees of astonishment.',
#   'token_count': 22,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 953,
#   'is_chapter_title': False},
#  {'text': '“Miss Brinklow . . .',
#   'token_count': 5,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 954,
#   'is_chapter_title': False},
#  {'text': 'Mr. Barnard, who is an American . . .',
#   'token_count': 9,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 955,
#   'is_chapter_title': False},
#  {'text': 'Mr. Mallinson . . .',
#   'token_count': 5,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 956,
#   'is_chapter_title': False},
#  {'text': 'and my own name is Conway.',
#   'token_count': 6,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 957,
#   'is_chapter_title': False},
#  {'text': 'We are all glad to see you, though the meeting is almost as puzzling as the fact of our being here at all.',
#   'token_count': 23,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 958,
#   'is_chapter_title': False},
#  {'text': 'Indeed, we were just about to make our way to your lamasery, so it is doubly fortunate.',
#   'token_count': 17,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 959,
#   'is_chapter_title': False},
#  {'text': 'If you could give us directions for the journey——”  “There is no need for that.',
#   'token_count': 15,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 960,
#   'is_chapter_title': False},
#  {'text': 'I shall be delighted to act as your guide.”',
#   'token_count': 9,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 961,
#   'is_chapter_title': False},
#  {'text': '“But I could not think of putting you to such trouble.',
#   'token_count': 11,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 962,
#   'is_chapter_title': False},
#  {'text': 'It is exceedingly kind of you, but if the distance is not far——”  “It is not far, but it is not easy either.',
#   'token_count': 23,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 963,
#   'is_chapter_title': False},
#  {'text': 'I shall esteem it an honour to accompany you and your friends.”',
#   'token_count': 12,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 964,
#   'is_chapter_title': False},
#  {'text': '“But really——”  “I must insist.”',
#   'token_count': 5,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 965,
#   'is_chapter_title': False},
#  {'text': 'Conway thought that the argument, in its context of place and circumstance, was in some danger of becoming ludicrous.',
#   'token_count': 19,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 966,
#   'is_chapter_title': False},
#  {'text': '“Very well,” he responded.',
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 967,
#   'is_chapter_title': False},
#  {'text': '“I’m sure we are all most obliged.”',
#   'token_count': 7,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 968,
#   'is_chapter_title': False},
#  {'text': 'Mallinson, who had been sombrely enduring these pleasantries, now interposed with something of the shrill acerbity of the barrack-square.',
#   'token_count': 19,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 969,
#   'is_chapter_title': False},
#  {'text': '“Our stay won’t be long,” he announced curtly.',
#   'token_count': 8,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 970,
#   'is_chapter_title': False},
#  {'text': '“We shall pay for anything we have, and we should like to hire some of your men to help us on our journey back.',
#   'token_count': 24,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 971,
#   'is_chapter_title': False},
#  {'text': 'We want to return to civilisation as soon as possible.”',
#   'token_count': 10,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 972,
#   'is_chapter_title': False},
#  {'text': '“And are you so very certain that you are away from it?”',
#   'token_count': 12,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 973,
#   'is_chapter_title': False},
#  {'text': 'The query, delivered with much suavity, only stung the youth to further sharpness.',
#   'token_count': 13,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 974,
#   'is_chapter_title': False},
#  {'text': '“I’m quite sure I’m far away from where I want to be, and so are we all.',
#   'token_count': 17,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 975,
#   'is_chapter_title': False},
#  {'text': 'We shall be grateful for temporary shelter, but we shall be more grateful still if you’ll provide means for us to return.',
#   'token_count': 22,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 976,
#   'is_chapter_title': False},
#  {'text': 'How long do you suppose the journey to India will take?”',
#   'token_count': 11,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 977,
#   'is_chapter_title': False},
#  {'text': '“I really could not say at all.”',
#   'token_count': 7,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 978,
#   'is_chapter_title': False},
#  {'text': '“Well, I hope we’re not going to have any trouble about it.',
#   'token_count': 12,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 979,
#   'is_chapter_title': False},
#  {'text': 'I’ve had some experience of hiring native porters, and we shall expect you to use your influence to get us a square deal.”',
#   'token_count': 23,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 980,
#   'is_chapter_title': False},
#  {'text': 'Conway felt that most of all this was rather needlessly truculent, and he was just about to intervene when the reply came, still with immense dignity: “I can only assure you, Mr. Mallinson, that you will be honourably treated and that ultimately you will have no regrets.”',
#   'token_count': 47,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 981,
#   'is_chapter_title': False},
#  {'text': '“_Ultimately?_” Mallinson exclaimed, pouncing on the word, but there was greater ease in avoiding a scene since wine and fruit were now on offer, having been unpacked by the marching party, stocky Tibetans in sheepskins, fur hats, and yak-skin boots.',
#   'token_count': 40,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 982,
#   'is_chapter_title': False},
#  {'text': 'The wine had a pleasant flavour, not unlike a good hock, while the fruit included mangoes, perfectly ripened and almost painfully delicious after so many hours of fasting.',
#   'token_count': 28,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 983,
#   'is_chapter_title': False},
#  {'text': 'Mallinson ate and drank with incurious relish; but Conway, relieved of immediate worries and reluctant to cherish distant ones, was wondering how mangoes could be cultivated at such an altitude.',
#   'token_count': 30,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 984,
#   'is_chapter_title': False},
#  {'text': 'He was also interested in the mountain beyond the valley; it was a sensational peak, by any standards, and he was surprised that some traveller had not made much of it in the kind of book that a journey in Tibet invariably elicits.',
#   'token_count': 43,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 985,
#   'is_chapter_title': False},
#  {'text': 'He climbed it in mind as he gazed, choosing a route by col and couloir until an exclamation from Mallinson drew his attention back to earth; he looked round then and saw that the Chinese had been earnestly regarding him.',
#   'token_count': 40,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 986,
#   'is_chapter_title': False},
#  {'text': '“You were contemplating the mountain, Mr. Conway?” came the enquiry.',
#   'token_count': 10,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 987,
#   'is_chapter_title': False},
#  {'text': '“Yes.',
#   'token_count': 1,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 988,
#   'is_chapter_title': False},
#  {'text': 'It’s a fine sight.',
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 989,
#   'is_chapter_title': False},
#  {'text': 'It has a name, I suppose?”',
#   'token_count': 6,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 990,
#   'is_chapter_title': False},
#  {'text': '“It is called Karakal.”',
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 991,
#   'is_chapter_title': False},
#  {'text': '“I don’t think I ever heard of it.',
#   'token_count': 8,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 992,
#   'is_chapter_title': False},
#  {'text': 'Is it very high?”',
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 993,
#   'is_chapter_title': False},
#  {'text': '“Over twenty-eight thousand feet.”',
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 994,
#   'is_chapter_title': False},
#  {'text': '“Indeed?',
#   'token_count': 1,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 995,
#   'is_chapter_title': False},
#  {'text': 'I didn’t realise there would be anything on that scale outside the Himalaya.',
#   'token_count': 13,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 996,
#   'is_chapter_title': False},
#  {'text': 'Has it been properly surveyed?',
#   'token_count': 5,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 997,
#   'is_chapter_title': False},
#  {'text': 'Whose are the measurements?”',
#   'token_count': 4,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 998,
#   'is_chapter_title': False},
#  {'text': '“Whose would you expect, my dear sir?',
#   'token_count': 7,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 999,
#   'is_chapter_title': False},
#  {'text': 'Is there anything incompatible between monasticism and trigonometry?”',
#   'token_count': 8,
#   'chapter_number': 0,
#   'chapter_title': '',
#   'section_number_in_chapter': 1,
#   'section_number_in_text': 1000,
#   'is_chapter_title': False},
#  ...]

# %%
for chapter in analyzer.chapters:
    print(f"Chapter {chapter.number}: {chapter.title[:30]}... {len(chapter.content)} characters")
