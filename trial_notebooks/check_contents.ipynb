# %%
import json
import os
from collections import Counter
from dataclasses import asdict
from dataclasses import dataclass
from dataclasses import field
from pathlib import Path
from pprint import pprint
from typing import Self

import structlog
from lxml import etree
from lxml.etree import HTMLParser
from lxml.etree import _Element as Element
from structlog.stdlib import BoundLogger

from utils.logger_config import configure_logger

BOOK_DIR = Path(os.environ.get("BOOK_DIR", "/books"))
file_name_counter = Counter()


def count_file_names(repo_dir: Path) -> None:
    for file_path in repo_dir.glob("*"):
        if file_path.is_file():
            file_name_counter.update([file_path.name])


def main():
    configure_logger()
    structlog.get_logger(__name__)

    for repo_dir in list(BOOK_DIR.glob("*")):
        if repo_dir.is_dir():
            count_file_names(repo_dir)
    pprint(file_name_counter)


if __name__ == "__main__":
    main()
# Out:
# Counter({'toc.xhtml': 31,
#          'imprint.xhtml': 31,
#          'colophon.xhtml': 31,
#          'toc_file_info.json': 31,
#          'titlepage.xhtml': 31,
#          'toc.json': 31,
#          'info.json': 31,
#          'uncopyright.xhtml': 31,
#          'halftitlepage.xhtml': 23,
#          'chapter-3.xhtml': 22,
#          'chapter-4.xhtml': 22,
#          'chapter-5.xhtml': 22,
#          'chapter-2.xhtml': 22,
#          'chapter-7.xhtml': 22,
#          'chapter-1.xhtml': 22,
#          'chapter-6.xhtml': 22,
#          'chapter-8.xhtml': 21,
#          'chapter-10.xhtml': 20,
#          'chapter-9.xhtml': 20,
#          'chapter-13.xhtml': 18,
#          'chapter-12.xhtml': 18,
#          'chapter-11.xhtml': 18,
#          'chapter-14.xhtml': 17,
#          'chapter-15.xhtml': 16,
#          'chapter-17.xhtml': 16,
#          'chapter-18.xhtml': 16,
#          'chapter-16.xhtml': 16,
#          'endnotes.xhtml': 15,
#          'chapter-20.xhtml': 15,
#          'chapter-19.xhtml': 15,
#          'chapter-22.xhtml': 15,
#          'chapter-21.xhtml': 15,
#          'chapter-23.xhtml': 13,
#          'chapter-27.xhtml': 12,
#          'chapter-25.xhtml': 12,
#          'chapter-24.xhtml': 12,
#          'chapter-26.xhtml': 12,
#          'chapter-28.xhtml': 11,
#          'dedication.xhtml': 9,
#          'chapter-30.xhtml': 9,
#          'chapter-29.xhtml': 9,
#          'chapter-32.xhtml': 8,
#          'chapter-33.xhtml': 8,
#          'chapter-31.xhtml': 8,
#          'introduction.xhtml': 7,
#          'chapter-35.xhtml': 7,
#          'chapter-34.xhtml': 7,
#          'preface.xhtml': 7,
#          'loi.xhtml': 6,
#          'chapter-36.xhtml': 6,
#          'chapter-2-1.xhtml': 5,
#          'chapter-1-7.xhtml': 5,
#          'chapter-2-2.xhtml': 5,
#          'chapter-2-3.xhtml': 5,
#          'chapter-2-4.xhtml': 5,
#          'chapter-2-5.xhtml': 5,
#          'chapter-1-3.xhtml': 5,
#          'chapter-1-1.xhtml': 5,
#          'chapter-1-5.xhtml': 5,
#          'chapter-1-2.xhtml': 5,
#          'chapter-1-6.xhtml': 5,
#          'chapter-1-4.xhtml': 5,
#          'chapter-3-4.xhtml': 4,
#          'chapter-1-8.xhtml': 4,
#          'chapter-2-6.xhtml': 4,
#          'book-12.xhtml': 2,
#          'book-6.xhtml': 2,
#          'book-10.xhtml': 2,
#          'chapter-84.xhtml': 2,
#          'chapter-70.xhtml': 2,
#          'chapter-79.xhtml': 2,
#          'chapter-74.xhtml': 2,
#          'chapter-71.xhtml': 2,
#          'chapter-72.xhtml': 2,
#          'chapter-85.xhtml': 2,
#          'chapter-82.xhtml': 2,
#          'chapter-69.xhtml': 2,
#          'chapter-78.xhtml': 2,
#          'chapter-73.xhtml': 2,
#          'chapter-81.xhtml': 2,
#          'chapter-77.xhtml': 2,
#          'chapter-68.xhtml': 2,
#          'chapter-76.xhtml': 2,
#          'chapter-75.xhtml': 2,
#          'chapter-80.xhtml': 2,
#          'chapter-83.xhtml': 2,
#          'translators-dedication.xhtml': 1,
#          'authors-dedication.xhtml': 1,
#          'chapter-2-15.xhtml': 1,
#          'chapter-2-17.xhtml': 1,
#          'chapter-2-14.xhtml': 1,
#          'chapter-2-16.xhtml': 1,
#          'afterword.xhtml': 1,
#          'translators-note.xhtml': 1,
#          'epilogue.xhtml': 1,
#          'chapter-3-13.xhtml': 1,
#          'part-5.xhtml': 1,
#          'chapter-5-4.xhtml': 1,
#          'part-4.xhtml': 1,
#          'the-murderer.xhtml': 1,
#          'the-piebald-horses.xhtml': 1,
#          'the-little-red-christmas-tree.xhtml': 1,
#          'the-army-ensign.xhtml': 1,
#          'how-i-became-an-actor.xhtml': 1,
#          'the-picture.xhtml': 1,
#          'the-jewess.xhtml': 1,
#          'the-laestrygonians.xhtml': 1,
#          'the-disciple.xhtml': 1,
#          'measles.xhtml': 1,
#          'the-last-word.xhtml': 1,
#          'easter-day.xhtml': 1,
#          'the-witch.xhtml': 1,
#          'the-horse-thieves.xhtml': 1,
#          'the-elephant.xhtml': 1,
#          'the-park-of-kings.xhtml': 1,
#          'sasha.xhtml': 1,
#          'a-clump-of-lilacs.xhtml': 1,
#          'an-evening-guest.xhtml': 1,
#          'the-bracelet-of-garnets.xhtml': 1,
#          'black-fog.xhtml': 1,
#          'the-white-poodle.xhtml': 1,
#          'the-garden-of-the-holy-virgin.xhtml': 1,
#          'tempting-providence.xhtml': 1,
#          'roach-hole.xhtml': 1,
#          'the-outrage.xhtml': 1,
#          'happiness.xhtml': 1,
#          'le-coq-dor.xhtml': 1,
#          'anathema.xhtml': 1,
#          'the-song-and-the-dance.xhtml': 1,
#          'the-idiot.xhtml': 1,
#          'dogs-happiness.xhtml': 1,
#          'autumn-flowers.xhtml': 1,
#          'a-sentimental-romance.xhtml': 1,
#          'the-old-city-of-marseilles.xhtml': 1,
#          'captain-ribnikov.xhtml': 1,
#          'sulamith.xhtml': 1,
#          'hamlet.xhtml': 1,
#          'a-slav-soul.xhtml': 1,
#          'emerald.xhtml': 1,
#          'demir-kaya.xhtml': 1,
#          'monte-carlo.xhtml': 1,
#          'allez.xhtml': 1,
#          'mechanical-justice.xhtml': 1,
#          'a-legend.xhtml': 1,
#          'the-river-of-life.xhtml': 1,
#          'cain.xhtml': 1,
#          'fables.xhtml': 1,
#          'chapter-4-10.xhtml': 1,
#          'chapter-9-8.xhtml': 1,
#          'chapter-8-8.xhtml': 1,
#          'chapter-10-12.xhtml': 1,
#          'chapter-7-10.xhtml': 1,
#          'chapter-7-8.xhtml': 1,
#          'chapter-6-2.xhtml': 1,
#          'chapter-11-10.xhtml': 1,
#          'chapter-8-2.xhtml': 1,
#          'chapter-11-8.xhtml': 1,
#          'book-2-introduction.xhtml': 1,
#          'editors-introduction.xhtml': 1,
#          'book-4-introduction.xhtml': 1,
#          'preface-3.xhtml': 1,
#          '2024-04-10_standardebooks_repositories-checkpoint.json': 1,
#          'the-mystery-of-hunters-lodge.xhtml': 1,
#          'the-kidnapped-prime-minister.xhtml': 1,
#          'the-million-dollar-bond-robbery.xhtml': 1,
#          'the-tragedy-at-marsdon-manor.xhtml': 1,
#          'the-jewel-robbery-at-the-grand-metropolitan.xhtml': 1,
#          'the-disappearance-of-mr-davenheim.xhtml': 1,
#          'the-adventure-of-the-egyptian-tomb.xhtml': 1,
#          'the-adventure-of-the-italian-nobleman.xhtml': 1,
#          'the-case-of-the-missing-will.xhtml': 1,
#          'the-adventure-of-the-cheap-flat.xhtml': 1,
#          'the-adventure-of-the-western-star.xhtml': 1,
#          'chapter-110.xhtml': 1,
#          'chapter-114.xhtml': 1,
#          'chapter-86.xhtml': 1,
#          'chapter-98.xhtml': 1,
#          'chapter-113.xhtml': 1,
#          'chapter-104.xhtml': 1,
#          'chapter-106.xhtml': 1,
#          'chapter-92.xhtml': 1,
#          'chapter-91.xhtml': 1,
#          'chapter-99.xhtml': 1,
#          'chapter-90.xhtml': 1,
#          'chapter-103.xhtml': 1,
#          'chapter-95.xhtml': 1,
#          'chapter-100.xhtml': 1,
#          'chapter-87.xhtml': 1,
#          'chapter-117.xhtml': 1,
#          'chapter-93.xhtml': 1,
#          'chapter-111.xhtml': 1,
#          'chapter-105.xhtml': 1,
#          'chapter-94.xhtml': 1,
#          'chapter-101.xhtml': 1,
#          'chapter-109.xhtml': 1,
#          'chapter-108.xhtml': 1,
#          'chapter-88.xhtml': 1,
#          'chapter-89.xhtml': 1,
#          'chapter-115.xhtml': 1,
#          'chapter-107.xhtml': 1,
#          'chapter-102.xhtml': 1,
#          'chapter-112.xhtml': 1,
#          'chapter-96.xhtml': 1,
#          'chapter-97.xhtml': 1,
#          'chapter-116.xhtml': 1})

# %%
import json
import os
from collections import Counter
from dataclasses import asdict
from dataclasses import dataclass
from dataclasses import field
from pathlib import Path
from pprint import pprint
from typing import Self

import structlog
from lxml import etree
from lxml.etree import HTMLParser
from lxml.etree import _Element as Element
from structlog.stdlib import BoundLogger

from utils.logger_config import configure_logger

BOOK_DIR = Path(os.environ.get("BOOK_DIR", "/books"))
file_name_counter = Counter()


def count_file_names(repo_dir: Path) -> None:
    for file_path in repo_dir.glob("*"):
        if file_path.is_file():
            file_name_counter.update([file_path.name])


def main():
    configure_logger()
    structlog.get_logger(__name__)

    for repo_dir in list(BOOK_DIR.glob("*")):
        if repo_dir.is_dir():
            count_file_names(repo_dir)
    pprint(file_name_counter)


if __name__ == "__main__":
    main()
