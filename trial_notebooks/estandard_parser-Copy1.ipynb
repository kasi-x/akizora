# %%
import json
from dataclasses import asdict
from dataclasses import dataclass
from dataclasses import field
from pathlib import Path
from typing import Optional

from lxml import etree
from lxml.etree import Element
from lxml.etree import HTMLParser

# import structlog
# from structlog.stdlib import BoundLogger

namespaces = {"xhtml": "http://www.w3.org/1999/xhtml"}


def show(element, level=0):
    print(etree.tostring(element, pretty_print=True, encoding=str))


title = "john-maynard-keynes_the-economic-consequences-of-the-peace"
path = Path(f"/home/user/dev/kasi-x/akizora/books/{title}/toc.xhtml")

with open(path) as file:
    xml_data = file.read().rstrip().encode("utf-8")


def find_root(xml_data: bytes = xml_data) -> Element:
    # MEMO: HTMLParser is easy for me more than lxml.etree.XMLParser.
    parser = HTMLParser(encoding="UTF-8")
    # WHYNOT: if I use xml.etree.ElementTree, I can read from utf-8 string, but I don't want to do mix-usage of xml.etree.ElementTree and lxml.etree.
    return etree.fromstring(xml_data, parser)


def parse_from_xml_data(query: str, xml_data: bytes = xml_data) -> list[Element]:
    return find_root(xml_data).xpath(query)


def find_file_title() -> str | None:
    return parse_from_xml_data("//html/head/title")[0].text


def find_chapters(append=None) -> list[Element]:
    if append:
        return parse_from_xml_data("//html/body/nav[@id='toc'][1]/ol/li" + append)
    return parse_from_xml_data("//html/body/nav[@id='toc'][1]/ol/li")


@dataclass
class Chapter:
    """input data format is like this <a href="text/chapter-3.xhtml"><span epub:type="z3998:roman">III</span>: The Conference</a>."""

    title: str
    href: str
    nest_level: int
    span: str
    subchapters: list["Chapter"] = field(default_factory=list)
    self_query: str | None = None  # for debug

    def __post_init__(self):
        self.subchapters = process_raw_chapters_into_formated(
            self.subchapters,
            self.nest_level + 1,
            self.self_query + "/ol/li" if self.self_query else None,
        )

    def to_dict(self):
        if self.subchapters:
            self.subchapters = [subchapter.to_dict() for subchapter in self.subchapters]  # type: ignore

        return asdict(self)


def process_raw_chapters_into_formated(
    raw_chapters, nest_level=0, self_query=None
) -> list[Chapter]:
    return [
        Chapter(
            title=raw_chapter.xpath("a/text()")[0] if raw_chapter.xpath("a/text()") else "",
            href=raw_chapter.xpath("a/@href")[0] if raw_chapter.xpath("a/@href") else "",
            nest_level=nest_level,
            span=raw_chapter.xpath("a/span/text()")[0]
            if raw_chapter.xpath("a/span/text()")
            else "",
            subchapters=raw_chapter.xpath("ol/li"),
            self_query=self_query + f"[{index}]" if self_query else None,
        )
        for index, raw_chapter in enumerate(raw_chapters, start=1)
    ]


# parse_from_xml_data("//html/body/nav[@id='toc'][1]/ol/li")


def create_dict_formated_chapters(chapters):
    return [chapter.to_dict() for chapter in chapters]


def create_formated_chapters() -> list[Chapter]:
    return process_raw_chapters_into_formated(
        find_chapters(), self_query="//html/body/nav[@id='toc'][1]/ol/li"
    )

# This is for debugging.
def show(element):
    if len(element) == 0:
        print("No elements are found.")
    if isinstance(element, list):
        print(f"{len(element)} elements are found.")
        print("{:=^30}".format(" Show Data "))
        for _i, e in enumerate(element, 1):
            print(f"{_i:=^30}")
            show(e)
    else:
        print(etree.tostring(element, pretty_print=True, encoding=str))

chapters = create_formated_chapters()

l = []
for c in chapters:
    l.append(c.to_dict())

import json
with open("test.json", "w") as fp:
     json.dump(l, fp)

from pprint import pprint

pprint(chapters)

# %%
chapters = create_formated_chapters()

l = []
for c in chapters:
    l.append(c.to_dict())

import json
with open("test.json", "w") as fp:
     json.dump(l, fp)

from pprint import pprint

pprint(chapters)

# %%
from pprint import pprint

pprint(chapters)

# %%
with open(Path(f"/home/user/dev/kasi-x/akizora/books/{title}/info.json")) as info_file:
    json.load(info_file)

# %%
with open(Path(f"/home/user/dev/kasi-x/akizora/books/{title}/info.json")) as info_file:
    toc_file_info = [info for info in json.load(info_file) if info["path"] == "toc.xhtml"]

# %%
from scrayping.github_api import GithubAPI

# %%
toc_url = f"https://api.github.com/repos/standardebooks/{title}/contents/src/epub/toc.xhtml?ref=master"
toc_data = GithubAPI().get_single_file_content_data(toc_url)
print(toc_data["content"])
# Out:
# 2024-04-11 21:23:38 [info     ] API Request                    method=GET module=github_api url=https://api.github.com/repos/standardebooks/john-maynard-keynes_the-economic-consequences-of-the-peace/contents/src/epub/toc.xhtml?ref=master
# 2024-04-11 21:23:39 [debug    ] API Request Successful         module=github_api status_code=200 url=https://api.github.com/repos/standardebooks/john-maynard-keynes_the-economic-consequences-of-the-peace/contents/src/epub/toc.xhtml?ref=master
# PD94bWwgdmVyc2lvbj0iMS4wIiBlbmNvZGluZz0idXRmLTgiPz4KPGh0bWwg
# eG1sbnM9Imh0dHA6Ly93d3cudzMub3JnLzE5OTkveGh0bWwiIHhtbG5zOmVw
# dWI9Imh0dHA6Ly93d3cuaWRwZi5vcmcvMjAwNy9vcHMiIGVwdWI6cHJlZml4
# PSJ6Mzk5ODogaHR0cDovL3d3dy5kYWlzeS5vcmcvejM5OTgvMjAxMi92b2Nh
# Yi9zdHJ1Y3R1cmUvLCBzZTogaHR0cHM6Ly9zdGFuZGFyZGVib29rcy5vcmcv
# dm9jYWIvMS4wIiB4bWw6bGFuZz0iZW4tVVMiPgoJPGhlYWQ+CgkJPHRpdGxl
# PlRhYmxlIG9mIENvbnRlbnRzPC90aXRsZT4KCTwvaGVhZD4KCTxib2R5IGVw
# dWI6dHlwZT0iZnJvbnRtYXR0ZXIiPgoJCTxuYXYgaWQ9InRvYyIgZXB1Yjp0
# eXBlPSJ0b2MiPgoJCQk8aDIgZXB1Yjp0eXBlPSJ0aXRsZSI+VGFibGUgb2Yg
# Q29udGVudHM8L2gyPgoJCQk8b2w+CgkJCQk8bGk+CgkJCQkJPGEgaHJlZj0i
# dGV4dC90aXRsZXBhZ2UueGh0bWwiPlRpdGxlcGFnZTwvYT4KCQkJCTwvbGk+
# CgkJCQk8bGk+CgkJCQkJPGEgaHJlZj0idGV4dC9pbXByaW50LnhodG1sIj5J
#  'git_url': 'https://api.github.com/repos/standardebooks/john-maynard-keynes_the-economic-consequences-of-the-peace/git/blobs/473246fdd33a25a230f1612f382dd62730f6855b',
#  'download_url': 'https://raw.githubusercontent.com/standardebooks/john-maynard-keynes_the-economic-consequences-of-the-peace/master/src/epub/toc.xhtml',
#  'type': 'file',
#  'content': '\nCQkJCQk8L2xpPgoJCQk ...
#  'encoding': 'base64',
#  '_links': {'self': 'https://api.github.com/repos/standardebooks/john-maynard-keynes_the-economic-consequences-of-the-peace/contents/src/epub/toc.xhtml?ref=master',
#   'git': 'https://api.github.com/repos/standardebooks/john-maynard-keynes_the-economic-consequences-of-the-peace/git/blobs/473246fdd33a25a230f1612f382dd62730f6855b',
#   'html': 'https://github.com/standardebooks/john-maynard-keynes_the-economic-consequences-of-the-peace/blob/master/src/epub/toc.xhtml'}}

# %%
toc_file_info
# Out:
# []

# %%
pprint(chapters)
# Out:
# [Chapter(title='Titlepage',
#          href='text/titlepage.xhtml',
#          nest_level=0,
#          span='',
#          subchapters=[],
#          self_query="//html/body/nav[@id='toc'][1]/ol/li[1]"),
#  Chapter(title='Imprint',
#          href='text/imprint.xhtml',
#          nest_level=0,
#          span='',
#          subchapters=[],
#          self_query="//html/body/nav[@id='toc'][1]/ol/li[2]"),
#  Chapter(title='Preface',
#          href='text/preface.xhtml',
#          nest_level=0,
#          span='',
#          subchapters=[],
#          self_query="//html/body/nav[@id='toc'][1]/ol/li[3]"),
#  Chapter(title='The Economic Consequences of the Peace',
#          href='text/halftitlepage.xhtml',
#          nest_level=0,
#          span='',
#          subchapters=[Chapter(title=': Introductory',
#                               href='text/chapter-1.xhtml',
#                               nest_level=1,
#                               span='I',
#                               subchapters=[],
#                               self_query="//html/body/nav[@id='toc'][1]/ol/li[4]/ol/li[1]"),
#                       Chapter(title=': Europe Before the War',
#                               href='text/chapter-2.xhtml',
#                               nest_level=1,
#                               span='II',
#                               subchapters=[Chapter(title=': Population',
#                                                    href='text/chapter-2.xhtml#chapter-2-1',
#                                                    nest_level=2,
#                                                    span='I',
#                                                    subchapters=[],
#                                                    self_query="//html/body/nav[@id='toc'][1]/ol/li[4]/ol/li[2]/ol/li[1]"),
#                                            Chapter(title=': Organization',
#                                                    href='text/chapter-2.xhtml#chapter-2-2',
#                                                    nest_level=2,
#                                                    span='II',
#                                                    subchapters=[],
#                                                    self_query="//html/body/nav[@id='toc'][1]/ol/li[4]/ol/li[2]/ol/li[2]"),
#                                            Chapter(title=': The Psychology of '
#                                                          'Society',
#                                                    href='text/chapter-2.xhtml#chapter-2-3',
#                                                    nest_level=2,
#                                                    span='III',
#                                                    subchapters=[],
#                                                    self_query="//html/body/nav[@id='toc'][1]/ol/li[4]/ol/li[2]/ol/li[3]"),
#                                            Chapter(title=': The Relation of '
#                                                          'the Old World to the '
#                                                          'New',
#                                                    href='text/chapter-2.xhtml#chapter-2-4',
#                                                    nest_level=2,
#                                                    span='IV',
#                                                    subchapters=[],
#                                                    self_query="//html/body/nav[@id='toc'][1]/ol/li[4]/ol/li[2]/ol/li[4]")],
#                               self_query="//html/body/nav[@id='toc'][1]/ol/li[4]/ol/li[2]"),
#                       Chapter(title=': The Conference',
#                               href='text/chapter-3.xhtml',
#                               nest_level=1,
#                               span='III',
#                               subchapters=[],
#                               self_query="//html/body/nav[@id='toc'][1]/ol/li[4]/ol/li[3]"),
#                       Chapter(title=': The Treaty',
#                               href='text/chapter-4.xhtml',
#                               nest_level=1,
#                               span='IV',
#                               subchapters=[],
#                               self_query="//html/body/nav[@id='toc'][1]/ol/li[4]/ol/li[4]"),
#                       Chapter(title=': Reparation',
#                               href='text/chapter-5.xhtml',
#                               nest_level=1,
#                               span='V',
#                               subchapters=[Chapter(title=': Undertakings Given '
#                                                          'Prior to the Peace '
#                                                          'Negotiations',
#                                                    href='text/chapter-5.xhtml#chapter-5-1',
#                                                    nest_level=2,
#                                                    span='I',
#                                                    subchapters=[],
#                                                    self_query="//html/body/nav[@id='toc'][1]/ol/li[4]/ol/li[5]/ol/li[1]"),
#                                            Chapter(title=': The Conference and '
#                                                          'the Terms of the '
#                                                          'Treaty',
#                                                    href='text/chapter-5.xhtml#chapter-5-2',
#                                                    nest_level=2,
#                                                    span='II',
#                                                    subchapters=[],
#                                                    self_query="//html/body/nav[@id='toc'][1]/ol/li[4]/ol/li[5]/ol/li[2]"),
#                                            Chapter(title=': Germany’s Capacity '
#                                                          'to Pay',
#                                                    href='text/chapter-5.xhtml#chapter-5-3',
#                                                    nest_level=2,
#                                                    span='III',
#                                                    subchapters=[],
#                                                    self_query="//html/body/nav[@id='toc'][1]/ol/li[4]/ol/li[5]/ol/li[3]"),
#                                            Chapter(title=': The Reparation '
#                                                          'Commission',
#                                                    href='text/chapter-5.xhtml#chapter-5-4',
#                                                    nest_level=2,
#                                                    span='IV',
#                                                    subchapters=[],
#                                                    self_query="//html/body/nav[@id='toc'][1]/ol/li[4]/ol/li[5]/ol/li[4]"),
#                                            Chapter(title=': The German '
#                                                          'Counterproposals',
#                                                    href='text/chapter-5.xhtml#chapter-5-5',
#                                                    nest_level=2,
#                                                    span='V',
#                                                    subchapters=[],
#                                                    self_query="//html/body/nav[@id='toc'][1]/ol/li[4]/ol/li[5]/ol/li[5]")],
#                               self_query="//html/body/nav[@id='toc'][1]/ol/li[4]/ol/li[5]"),
#                       Chapter(title=': Europe After the Treaty',
#                               href='text/chapter-6.xhtml',
#                               nest_level=1,
#                               span='VI',
#                               subchapters=[],
#                               self_query="//html/body/nav[@id='toc'][1]/ol/li[4]/ol/li[6]"),
#                       Chapter(title=': Remedies',
#                               href='text/chapter-7.xhtml',
#                               nest_level=1,
#                               span='VII',
#                               subchapters=[],
#                               self_query="//html/body/nav[@id='toc'][1]/ol/li[4]/ol/li[7]")],
#          self_query="//html/body/nav[@id='toc'][1]/ol/li[4]"),
#  Chapter(title='Endnotes',
#          href='text/endnotes.xhtml',
#          nest_level=0,
#          span='',
#          subchapters=[],
#          self_query="//html/body/nav[@id='toc'][1]/ol/li[5]"),
#  Chapter(title='Colophon',
#          href='text/colophon.xhtml',
#          nest_level=0,
#          span='',
#          subchapters=[],
#          self_query="//html/body/nav[@id='toc'][1]/ol/li[6]"),
#  Chapter(title='Uncopyright',
#          href='text/uncopyright.xhtml',
#          nest_level=0,
#          span='',
#          subchapters=[],
#          self_query="//html/body/nav[@id='toc'][1]/ol/li[7]")]

# %%
l = []
for c in chapters:
    l.append(c.to_dict())

import json
with open("test.json", "w") as fp:
     json.dump(l, fp)

# %%
import json
with open("test.json", "w") as fp:
     json.dump(l, fp)

# %%
l.dump()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 l.dump()
#
# AttributeError: 'list' object has no attribute 'dump'

# %%
chapters
