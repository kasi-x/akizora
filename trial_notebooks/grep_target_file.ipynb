# %%
import json
import os
from collections import Counter
from dataclasses import asdict
from dataclasses import dataclass
from dataclasses import field
from pathlib import Path
from pprint import pprint
from typing import Self

import structlog
from lxml import etree
from lxml.etree import HTMLParser
from lxml.etree import _Element as Element
from structlog.stdlib import BoundLogger

from utils.data_io import read_dict
from utils.data_io import save_chunk
from utils.data_io import save_xhtml
from utils.logger_config import configure_logger

BOOK_DIR = Path(os.environ.get("BOOK_DIR", "/books"))
file_name_counter = Counter()


def grep_chapter_books():
    good_repos = []
    for repo_dir in list(BOOK_DIR.glob("*")):
        if repo_dir.is_dir():
            for file_path in repo_dir.glob("*"):
                if file_path.is_file() and file_path.name.startswith("chapter-1"):
                    good_repos.append(repo_dir)
                    break
    return good_repos


def get_max_nest_level(chapters):
    max_result = 0
    for chapter in chapters:
        if sub_chapters := chapter.get("subchapters"):
            max_result = max(get_max_nest_level(sub_chapters), max_result)
        else:
            max_result = max(chapter["nest_level"], max_result)
    return max_result


def grep_shallow_nested_books(repos: list[Path]):
    results = []
    for repo_dir in repos:
        chapters = read_dict(repo_dir / "toc.json")
        print(f"f{repo_dir} has {len(chapters)} chapters.")
        if not chapters:
            continue
        nest_level = get_max_nest_level(chapters)
        if 1 <= nest_level < 2:
            print(f"{repo_dir} append: {nest_level}")
            results.append(repo_dir)
        else:
            print(f"{repo_dir} has deep nest level: {nest_level}")
    return results


def main():
    configure_logger()
    logger = structlog.get_logger(__name__)
    good_repos = grep_chapter_books()
    good_repos = grep_shallow_nested_books(good_repos)
    pprint(good_repos)
    data = [str(data) for data in good_repos]
    save_chunk(data, BOOK_DIR / "easy_readable_books.json", logger)


if __name__ == "__main__":
    main()
# Out:
# f/home/user/dev/kasi-x/akizora/books/aleksandr-kuprin_yama_bernard-guilbert-guerney has 13 chapters.
# /home/user/dev/kasi-x/akizora/books/aleksandr-kuprin_yama_bernard-guilbert-guerney has deep nest level: 2
# f/home/user/dev/kasi-x/akizora/books/agatha-christie_the-mystery-of-the-blue-train has 6 chapters.
# /home/user/dev/kasi-x/akizora/books/agatha-christie_the-mystery-of-the-blue-train append: 1
# f/home/user/dev/kasi-x/akizora/books/agatha-christie_the-man-in-the-brown-suit has 7 chapters.
# /home/user/dev/kasi-x/akizora/books/agatha-christie_the-man-in-the-brown-suit append: 1
# f/home/user/dev/kasi-x/akizora/books/alexandre-dumas_the-three-musketeers_william-robson has 8 chapters.
# /home/user/dev/kasi-x/akizora/books/alexandre-dumas_the-three-musketeers_william-robson append: 1
# f/home/user/dev/kasi-x/akizora/books/aldous-huxley_those-barren-leaves has 9 chapters.
# /home/user/dev/kasi-x/akizora/books/aldous-huxley_those-barren-leaves append: 1
# f/home/user/dev/kasi-x/akizora/books/agatha-christie_the-murder-on-the-links has 6 chapters.
# /home/user/dev/kasi-x/akizora/books/agatha-christie_the-murder-on-the-links append: 1
# f/home/user/dev/kasi-x/akizora/books/aleksandr-kuprin_the-duel_george-allen-unwin has 28 chapters.
# /home/user/dev/kasi-x/akizora/books/aleksandr-kuprin_the-duel_george-allen-unwin has deep nest level: 0
# f/home/user/dev/kasi-x/akizora/books/aldous-huxley_crome-yellow has 34 chapters.
# /home/user/dev/kasi-x/akizora/books/aldous-huxley_crome-yellow has deep nest level: 0
# f/home/user/dev/kasi-x/akizora/books/a-w-tozer_the-pursuit-of-god has 9 chapters.
# /home/user/dev/kasi-x/akizora/books/a-w-tozer_the-pursuit-of-god append: 1
# f/home/user/dev/kasi-x/akizora/books/agatha-christie_the-mysterious-affair-at-styles has 7 chapters.
# /home/user/dev/kasi-x/akizora/books/agatha-christie_the-mysterious-affair-at-styles append: 1
# f/home/user/dev/kasi-x/akizora/books/a-a-milne_winnie-the-pooh has 7 chapters.
# /home/user/dev/kasi-x/akizora/books/a-a-milne_winnie-the-pooh append: 1
# f/home/user/dev/kasi-x/akizora/books/alexander-mackenzie_journals has 10 chapters.
# /home/user/dev/kasi-x/akizora/books/alexander-mackenzie_journals has deep nest level: 2
# f/home/user/dev/kasi-x/akizora/books/alain-rene-lesage_gil-blas_tobias-smollett has 8 chapters.
# /home/user/dev/kasi-x/akizora/books/alain-rene-lesage_gil-blas_tobias-smollett has deep nest level: 2
# f/home/user/dev/kasi-x/akizora/books/a-merritt_the-moon-pool has 8 chapters.
# /home/user/dev/kasi-x/akizora/books/a-merritt_the-moon-pool append: 1
# f/home/user/dev/kasi-x/akizora/books/alexander-hamilton_john-jay_james-madison_the-federalist-papers has 8 chapters.
# /home/user/dev/kasi-x/akizora/books/alexander-hamilton_john-jay_james-madison_the-federalist-papers append: 1
# f/home/user/dev/kasi-x/akizora/books/adam-smith_the-wealth-of-nations has 9 chapters.
# /home/user/dev/kasi-x/akizora/books/adam-smith_the-wealth-of-nations has deep nest level: 6
# f/home/user/dev/kasi-x/akizora/books/agatha-christie_the-secret-adversary has 6 chapters.
# /home/user/dev/kasi-x/akizora/books/agatha-christie_the-secret-adversary append: 1
# f/home/user/dev/kasi-x/akizora/books/alexander-pushkin_eugene-onegin_henry-spalding has 9 chapters.
# /home/user/dev/kasi-x/akizora/books/alexander-pushkin_eugene-onegin_henry-spalding has deep nest level: 3
# f/home/user/dev/kasi-x/akizora/books/john-maynard-keynes_the-economic-consequences-of-the-peace has 7 chapters.
# /home/user/dev/kasi-x/akizora/books/john-maynard-keynes_the-economic-consequences-of-the-peace has deep nest level: 2
# f/home/user/dev/kasi-x/akizora/books/aldous-huxley_antic-hay has 6 chapters.
# /home/user/dev/kasi-x/akizora/books/aldous-huxley_antic-hay append: 1
# f/home/user/dev/kasi-x/akizora/books/agatha-christie_the-murder-of-roger-ackroyd has 7 chapters.
# /home/user/dev/kasi-x/akizora/books/agatha-christie_the-murder-of-roger-ackroyd append: 1
# f/home/user/dev/kasi-x/akizora/books/alexandre-dumas_the-black-tulip_p-f-collier-and-son has 37 chapters.
# /home/user/dev/kasi-x/akizora/books/alexandre-dumas_the-black-tulip_p-f-collier-and-son has deep nest level: 0
# f/home/user/dev/kasi-x/akizora/books/alan-sullivan_the-jade-god has 18 chapters.
# /home/user/dev/kasi-x/akizora/books/alan-sullivan_the-jade-god has deep nest level: 0
# f/home/user/dev/kasi-x/akizora/books/agatha-christie_the-big-four has 22 chapters.
# /home/user/dev/kasi-x/akizora/books/agatha-christie_the-big-four has deep nest level: 0
# f/home/user/dev/kasi-x/akizora/books/alexander-berkman_the-bolshevik-myth has 7 chapters.
# /home/user/dev/kasi-x/akizora/books/alexander-berkman_the-bolshevik-myth has deep nest level: 2
# f/home/user/dev/kasi-x/akizora/books/alexandre-dumas_the-count-of-monte-cristo_chapman-and-hall has 122 chapters.
# /home/user/dev/kasi-x/akizora/books/alexandre-dumas_the-count-of-monte-cristo_chapman-and-hall has deep nest level: 0
# f/home/user/dev/kasi-x/akizora/books/a-a-milne_the-red-house-mystery has 6 chapters.
# /home/user/dev/kasi-x/akizora/books/a-a-milne_the-red-house-mystery append: 1
# [PosixPath('/home/user/dev/kasi-x/akizora/books/agatha-christie_the-mystery-of-the-blue-train'),
#  PosixPath('/home/user/dev/kasi-x/akizora/books/agatha-christie_the-man-in-the-brown-suit'),
#  PosixPath('/home/user/dev/kasi-x/akizora/books/alexandre-dumas_the-three-musketeers_william-robson'),
#  PosixPath('/home/user/dev/kasi-x/akizora/books/aldous-huxley_those-barren-leaves'),
#  PosixPath('/home/user/dev/kasi-x/akizora/books/agatha-christie_the-murder-on-the-links'),
#  PosixPath('/home/user/dev/kasi-x/akizora/books/a-w-tozer_the-pursuit-of-god'),
#  PosixPath('/home/user/dev/kasi-x/akizora/books/agatha-christie_the-mysterious-affair-at-styles'),
#  PosixPath('/home/user/dev/kasi-x/akizora/books/a-a-milne_winnie-the-pooh'),
#  PosixPath('/home/user/dev/kasi-x/akizora/books/a-merritt_the-moon-pool'),
#  PosixPath('/home/user/dev/kasi-x/akizora/books/alexander-hamilton_john-jay_james-madison_the-federalist-papers'),
#  PosixPath('/home/user/dev/kasi-x/akizora/books/agatha-christie_the-secret-adversary'),
#  PosixPath('/home/user/dev/kasi-x/akizora/books/aldous-huxley_antic-hay'),
#  PosixPath('/home/user/dev/kasi-x/akizora/books/agatha-christie_the-murder-of-roger-ackroyd'),
#  PosixPath('/home/user/dev/kasi-x/akizora/books/a-a-milne_the-red-house-mystery')]
# 2024-04-15 10:29.42 [info     ] Saved data.                    [__main__] path=PosixPath('/home/user/dev/kasi-x/akizora/books/easy_readable_books.json')
# 2024-04-15 10:29.42 [info     ] Saved data.                    [__main__] path=PosixPath('/home/user/dev/kasi-x/akizora/books/easy_readable_books.json')
# 2024-04-15 10:29.42 [info     ] Saved data.                    [__main__] path=PosixPath('/home/user/dev/kasi-x/akizora/books/easy_readable_books.json')
# 2024-04-15 10:29.42 [info     ] Saved data.                    [__main__] path=PosixPath('/home/user/dev/kasi-x/akizora/books/easy_readable_books.json')
# 2024-04-15 10:29.42 [info     ] Saved data.                    [__main__] path=PosixPath('/home/user/dev/kasi-x/akizora/books/easy_readable_books.json')
# 2024-04-15 10:29.42 [info     ] Saved data.                    [__main__] path=PosixPath('/home/user/dev/kasi-x/akizora/books/easy_readable_books.json')
# 2024-04-15 10:29.42 [info     ] Saved data.                    [__main__] path=PosixPath('/home/user/dev/kasi-x/akizora/books/easy_readable_books.json')
# 2024-04-15 10:29.42 [info     ] Saved data.                    [__main__] path=PosixPath('/home/user/dev/kasi-x/akizora/books/easy_readable_books.json')
# 2024-04-15 10:29.42 [info     ] Saved data.                    [__main__] path=PosixPath('/home/user/dev/kasi-x/akizora/books/easy_readable_books.json')
