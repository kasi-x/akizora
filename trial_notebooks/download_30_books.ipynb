# %%
import base64
import json
import os
from datetime import datetime
from pathlib import Path

import structlog
from structlog.stdlib import BoundLogger

from scrayping.github_api import ContentData
from scrayping.github_api import FileInfo
from scrayping.github_api import GithubApiManager
from scrayping.github_api import GithubApiUrl
from scrayping.github_api import RepositoryInfo
from utils.logger_config import configure_logger

BOOK_DIR = os.environ.get("BOOK_DIR", "/books")


def save_chunk(
    data: list[FileInfo] | ContentData | list[RepositoryInfo], path: Path, logger: BoundLogger
) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)
    with open(path, "w") as fp:
        json.dump(data, fp)
    if logger:
        logger.info("Saved data.", path=path)


def save_xhtml(data: str, path: Path, logger: BoundLogger) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)
    with open(path, "w") as fp:
        fp.write(data)
    if logger:
        logger.info("Saved data.", path=path)


def read_dict(path, logger=None) -> list[FileInfo | RepositoryInfo]:
    if logger:
        logger.info("Reading data.", path=path)
    with open(path) as fp:
        return json.load(fp)


def build_text_file_tree_url(book_name: str) -> GithubApiUrl:
    TEXT_FILE_DIR = "src/epub/text"
    BASE_URL = f"https://api.github.com/repos/standardebooks/{book_name}/git/trees/master"
    return BASE_URL + ":" + TEXT_FILE_DIR


def build_toc_file_url(book_name: str) -> GithubApiUrl:
    TOC_FILE_DIR = "src/epub/toc.xhtml"
    BASE_URL = f"https://api.github.com/repos/standardebooks/{book_name}/git/trees/master"
    return BASE_URL + ":" + TOC_FILE_DIR


def tree_info_path(book_name: str) -> Path:
    return tarfetch_book_dir(book_name) / "info.json"


def tarfetch_book_dir(book_name: str) -> Path:
    return Path(f"{BOOK_DIR}/{book_name}")


def scrape_files(
    book_name: str, force=False, logger: BoundLogger = structlog.get_logger(__name__)
) -> None:
    tree_info_chunk = read_dict(tree_info_path(book_name), logger)

    for each_file_info in tree_info_chunk:
        github = GithubApiManager()
        try:
            # EXAMPLE: books/john-maynard-keynes_the-economic-consequences-of-the-peace/chapter-1.xhtml
            tarfetch_path = tarfetch_book_dir(book_name) / each_file_info["path"]
            if not force and tarfetch_path.exists():
                logger.info(
                    "File already exists.",
                    path=tarfetch_path,
                    book_name=book_name,
                    fiil_name=tarfetch_path.name,
                )
                continue
            url = github.valivade_url(each_file_info["url"], "standardebooks", book_name)
            content_data = github.fetch_single_file_content_data(url)
            save_xhtml(
                base64.b64decode(content_data["content"]).decode("utf-8"), tarfetch_path, logger
            )
        except Exception as e:
            logger.exception(
                "Failed to process file.",
                at="scrape_files",
                file_path=each_file_info["path"],
                error=str(e),
            )


def save_tree_info(
    book_name: str, force=False, logger: BoundLogger = structlog.get_logger(__name__)
) -> None:
    if not force and tree_info_path(book_name).exists():
        logger.info(
            "Tree_info already exists.", path=tree_info_path(book_name), book_name=book_name
        )
        return
    text_file_tree_url = build_text_file_tree_url(book_name)
    save_chunk(
        GithubApiManager().fetch_file_tree_info(text_file_tree_url),
        tree_info_path(book_name),
        logger,
    )
    return


def fetch_raw_toc_file(
    book_name: str, force: bool = False, logger: BoundLogger = structlog.get_logger(__name__)
) -> None:
    if not force and Path(f"{BOOK_DIR}/{book_name}/toc.xhtml").exists():
        logger.info("toc.xhtml already exists.", book_name=book_name)
        return
    toc_file_url = build_toc_file_url(book_name)
    toc_file_info = GithubApiManager().fetch_single_file_content_data(toc_file_url)
    toc_file_info["content"] = base64.b64decode(toc_file_info["content"]).decode("utf-8")

    save_chunk(toc_file_info, Path(f"{BOOK_DIR}/{book_name}/toc_file_info.json"), logger)
    save_xhtml(toc_file_info["content"], Path(f"{BOOK_DIR}/{book_name}/toc.xhtml"), logger)


def fetch_all_repositories(
    force=False, logger: BoundLogger = structlog.get_logger(__name__)
) -> None:
    today = datetime.now().strftime("%Y-%m-%d")
    if not force and Path(f"{BOOK_DIR}/{today}_standardebooks_repositories.json").exists():
        return
    github = GithubApiManager()
    repositories = github.fetch_all_user_repositories("standardebooks")
    save_chunk(repositories, Path(f"{BOOK_DIR}/{today}_standardebooks_repositories.json"), logger)


def fetch_30_repositories(
    logger: BoundLogger = structlog.get_logger(__name__),
) -> list[RepositoryInfo]:
    file_path = Path(f"{BOOK_DIR}/trial_standardebooks_repositories.json")
    if file_path.exists():
        return read_dict(Path(f"{BOOK_DIR}/trial_standardebooks_repositories.json"), logger)  # type: ignore
    github = GithubApiManager()
    repositories = github.fetch_user_repositories("standardebooks")
    save_chunk(repositories, file_path, logger)

    # import pprint
    # pprint.pprint(repositories)
    return repositories


def fetch_book_data(book_name: str, logger: BoundLogger = structlog.get_logger(__name__)) -> None:
    fetch_raw_toc_file(book_name, False, logger)
    save_tree_info(book_name, False, logger)
    scrape_files(book_name, False, logger)


def main():
    configure_logger()

    logger = structlog.get_logger(__name__)

    repos = fetch_30_repositories(logger)
    for repo in repos:
        book_name = repo["name"]
        print(book_name)
        fetch_book_data(book_name, logger)

    # save_chunk(repositories, Path(f"{BOOK_DIR}/{today}_standardebooks_repositories.json"), logger)

    # fetch_all_repositories(False, logger)


if __name__ == "__main__":
    main()
# Out:
# 2024-04-12 10:09.35 [info     ] API Request                    [scrayping.github_api] method=GET module=github_api url=https://api.github.com/users/standardebooks/repos
# 2024-04-12 10:09.35 [info     ] API Request                    [scrayping.github_api] method=GET module=github_api url=https://api.github.com/users/standardebooks/repos
# 2024-04-12 10:09.35 [info     ] API Request                    [scrayping.github_api] method=GET module=github_api url=https://api.github.com/users/standardebooks/repos
# Starting new HTTPS connection (1): api.github.com:443
# Starting new HTTPS connection (1): api.github.com:443
# Starting new HTTPS connection (1): api.github.com:443
# https://api.github.com:443 "GET /users/standardebooks/repos HTTP/1.1" 200 None
# https://api.github.com:443 "GET /users/standardebooks/repos HTTP/1.1" 200 None
# https://api.github.com:443 "GET /users/standardebooks/repos HTTP/1.1" 200 None
# 2024-04-12 10:09.36 [debug    ] API Request Successful         [scrayping.github_api] module=github_api status_code=200 url=https://api.github.com/users/standardebooks/repos
# 2024-04-12 10:09.36 [debug    ] API Request Successful         [scrayping.github_api] module=github_api status_code=200 url=https://api.github.com/users/standardebooks/repos
# 2024-04-12 10:09.36 [debug    ] API Request Successful         [scrayping.github_api] module=github_api status_code=200 url=https://api.github.com/users/standardebooks/repos
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[7], line 177
#     171     # save_chunk(repositories, Path(f"{BOOK_DIR}/{today}_standardebooks_repositories.json"), logger)
#     172
#     173     # fetch_all_repositories(False, logger)
#     176 if __name__ == "__main__":
# --> 177     main()
#
# Cell In[7], line 165, in main()
#     161 configure_logger()
#     163 logger = structlog.get_logger(__name__)
# --> 165 repos = fetch_30_repositories(logger)
#     166 for repo in repos:
#     167     book_name = repo["name"]
#
# Cell In[7], line 147, in fetch_30_repositories(logger)
#     145 github = GithubApiManager()
#     146 repositories = github.fetch_user_repositories("standardebooks")
# --> 147 save_chunk(repositories, file_path, logger)
#     149 # import pprint
#     150 # pprint.pprint(repositories)
#     151 return repositories
#
# Cell In[7], line 23, in save_chunk(data, path, logger)
#      20 def save_chunk(
#      21     data: list[FileInfo] | ContentData | list[RepositoryInfo], path: Path, logger: BoundLogger
#      22 ) -> None:
# ---> 23     path.parent.mkdir(parents=True, exist_ok=True)
#      24     with open(path, "w") as fp:
#      25         json.dump(data, fp)
#
# File ~/.rye/py/cpython@3.12.2/lib/python3.12/pathlib.py:1311, in Path.mkdir(self, mode, parents, exist_ok)
#    1307 """
#    1308 Create a new directory at this given path.
#    1309 """
#    1310 try:
# -> 1311     os.mkdir(self, mode)
#    1312 except FileNotFoundError:
#    1313     if not parents or self.parent == self:
#
# PermissionError: [Errno 13] Permission denied: '/books'

# %%
configure_logger()

logger = structlog.get_logger(__name__)

repos = fetch_30_repositories(logger)
for repo in repos:
    book_name = repo["name"]
    fetch_raw_toc_file(book_name, False, logger)
    save_tree_info(book_name, False, logger)
# Out:
# 2024-04-12 09:51.04 [info     ] API Request                    [scrayping.github_api] method=GET module=github_api url=https://api.github.com/users/standardebooks/repos
# 2024-04-12 09:51.04 [info     ] API Request                    [scrayping.github_api] method=GET module=github_api url=https://api.github.com/users/standardebooks/repos
# Starting new HTTPS connection (1): api.github.com:443
# Starting new HTTPS connection (1): api.github.com:443
# https://api.github.com:443 "GET /users/standardebooks/repos HTTP/1.1" 200 None
# https://api.github.com:443 "GET /users/standardebooks/repos HTTP/1.1" 200 None
# 2024-04-12 09:51.05 [debug    ] API Request Successful         [scrayping.github_api] module=github_api status_code=200 url=https://api.github.com/users/standardebooks/repos
# 2024-04-12 09:51.05 [debug    ] API Request Successful         [scrayping.github_api] module=github_api status_code=200 url=https://api.github.com/users/standardebooks/repos
# [{'description': 'Epub source for the Standard Ebooks edition of The Red House '
#                  'Mystery, by A. A. Milne',
#   'name': 'a-a-milne_the-red-house-mystery',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/a-a-milne_the-red-house-mystery'},
#  {'description': 'Epub source for the Standard Ebooks edition of Winnie the '
#                  'Pooh, by A. A. Milne',
#   'name': 'a-a-milne_winnie-the-pooh',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/a-a-milne_winnie-the-pooh'},
#  {'description': 'Epub source for the Standard Ebooks edition of The Moon '
#                  'Pool, by A. Merritt',
#   'name': 'a-merritt_the-moon-pool',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/a-merritt_the-moon-pool'},
#  {'description': 'Epub source for the Standard Ebooks edition of The Pursuit '
#                  'of God, by A. W. Tozer',
#   'name': 'a-w-tozer_the-pursuit-of-god',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/a-w-tozer_the-pursuit-of-god'},
#  {'description': 'Epub source for the Standard Ebooks edition of Pan Tadeusz, '
#                  'by Adam Mickiewicz. Translated by Maude Ashurst Biggs',
#   'name': 'adam-mickiewicz_pan-tadeusz_maude-ashurst-biggs',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/adam-mickiewicz_pan-tadeusz_maude-ashurst-biggs'},
#  {'description': 'Epub source for the Standard Ebooks edition of The Wealth of '
#                  'Nations, by Adam Smith',
#   'name': 'adam-smith_the-wealth-of-nations',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/adam-smith_the-wealth-of-nations'},
#  {'description': 'Epub source for the Standard Ebooks edition of Fables, by '
#                  'Aesop. Translated by V. S. Vernon Jones',
#   'name': 'aesop_fables_v-s-vernon-jones',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/aesop_fables_v-s-vernon-jones'},
#  {'description': 'Epub source for the Standard Ebooks edition of Poirot '
#                  'Investigates, by Agatha Christie',
#   'name': 'agatha-christie_poirot-investigates',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/agatha-christie_poirot-investigates'},
#  {'description': 'Epub source for the Standard Ebooks edition of The Big Four, '
#                  'by Agatha Christie',
#   'name': 'agatha-christie_the-big-four',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/agatha-christie_the-big-four'},
#  {'description': 'Epub source for the Standard Ebooks edition of The Man in '
#                  'the Brown Suit, by Agatha Christie',
#   'name': 'agatha-christie_the-man-in-the-brown-suit',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/agatha-christie_the-man-in-the-brown-suit'},
#  {'description': 'Epub source for the Standard Ebooks edition of The Murder of '
#                  'Roger Ackroyd, by Agatha Christie',
#   'name': 'agatha-christie_the-murder-of-roger-ackroyd',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/agatha-christie_the-murder-of-roger-ackroyd'},
#  {'description': 'Epub source for the Standard Ebooks edition of The Murder on '
#                  'the Links, by Agatha Christie',
#   'name': 'agatha-christie_the-murder-on-the-links',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/agatha-christie_the-murder-on-the-links'},
#  {'description': 'Epub source for the Standard Ebooks edition of The '
#                  'Mysterious Affair at Styles, by Agatha Christie',
#   'name': 'agatha-christie_the-mysterious-affair-at-styles',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/agatha-christie_the-mysterious-affair-at-styles'},
#  {'description': 'Epub source for the Standard Ebooks edition of The Mystery '
#                  'of the Blue Train, by Agatha Christie',
#   'name': 'agatha-christie_the-mystery-of-the-blue-train',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/agatha-christie_the-mystery-of-the-blue-train'},
#  {'description': 'Epub source for the Standard Ebooks edition of The Secret '
#                  'Adversary, by Agatha Christie',
#   'name': 'agatha-christie_the-secret-adversary',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/agatha-christie_the-secret-adversary'},
#  {'description': 'Epub source for the Standard Ebooks edition of Gil Blas, by '
#                  'Alain-René Lesage. Translated by Tobias Smollett',
#   'name': 'alain-rene-lesage_gil-blas_tobias-smollett',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/alain-rene-lesage_gil-blas_tobias-smollett'},
#  {'description': 'Epub source for the Standard Ebooks edition of The Jade God, '
#                  'by Alan Sullivan',
#   'name': 'alan-sullivan_the-jade-god',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/alan-sullivan_the-jade-god'},
#  {'description': 'Epub source for the Standard Ebooks edition of Antic Hay, by '
#                  'Aldous Huxley',
#   'name': 'aldous-huxley_antic-hay',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/aldous-huxley_antic-hay'},
#  {'description': 'Epub source for the Standard Ebooks edition of Crome Yellow, '
#                  'by Aldous Huxley',
#   'name': 'aldous-huxley_crome-yellow',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/aldous-huxley_crome-yellow'},
#  {'description': 'Epub source for the Standard Ebooks edition of Those Barren '
#                  'Leaves, by Aldous Huxley',
#   'name': 'aldous-huxley_those-barren-leaves',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/aldous-huxley_those-barren-leaves'},
#  {'description': 'Epub source for the Standard Ebooks edition of Short '
#                  'Fiction, by Aleksandr Kuprin. Translated by S. Koteliansky, '
#                  'J. M. Murry, Stephen Graham, Rosa Savory Graham, Leo '
#                  'Pasvolsky, Douglas Ashby, The Living Age, B. Guilbert '
#                  'Guerney, Alexander Gagarine and Malcolm W. Davis',
#   'name': 'aleksandr-kuprin_short-fiction_s-koteliansky_j-m-murry_stephen-graham_rosa-savory-graham_leo-pasvols',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/aleksandr-kuprin_short-fiction_s-koteliansky_j-m-murry_stephen-graham_rosa-savory-graham_leo-pasvols'},
#  {'description': 'Epub source for the Standard Ebooks edition of The Duel, by '
#                  'Aleksandr Kuprin. Translated by George Allen & Unwin',
#   'name': 'aleksandr-kuprin_the-duel_george-allen-unwin',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/aleksandr-kuprin_the-duel_george-allen-unwin'},
#  {'description': 'Epub source for the Standard Ebooks edition of Yama, by '
#                  'Aleksandr Kuprin. Translated by Bernard Guilbert Guerney',
#   'name': 'aleksandr-kuprin_yama_bernard-guilbert-guerney',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/aleksandr-kuprin_yama_bernard-guilbert-guerney'},
#  {'description': 'Epub source for the Standard Ebooks edition of The Bolshevik '
#                  'Myth, by Alexander Berkman',
#   'name': 'alexander-berkman_the-bolshevik-myth',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/alexander-berkman_the-bolshevik-myth'},
#  {'description': 'Epub source for the Standard Ebooks edition of The '
#                  'Federalist Papers, by Alexander Hamilton, John Jay, and '
#                  'James Madison',
#   'name': 'alexander-hamilton_john-jay_james-madison_the-federalist-papers',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/alexander-hamilton_john-jay_james-madison_the-federalist-papers'},
#  {'description': 'Epub source for the Standard Ebooks edition of Journals, by '
#                  'Alexander Mackenzie',
#   'name': 'alexander-mackenzie_journals',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/alexander-mackenzie_journals'},
#  {'description': 'Epub source for the Standard Ebooks edition of Eugene '
#                  'Onegin, by Alexander Pushkin. Translated by Henry Spalding',
#   'name': 'alexander-pushkin_eugene-onegin_henry-spalding',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/alexander-pushkin_eugene-onegin_henry-spalding'},
#  {'description': 'Epub source for the Standard Ebooks edition of The Black '
#                  'Tulip, by Alexandre Dumas. Translated by P. F. Collier & Son',
#   'name': 'alexandre-dumas_the-black-tulip_p-f-collier-and-son',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/alexandre-dumas_the-black-tulip_p-f-collier-and-son'},
#  {'description': 'Epub source for the Standard Ebooks edition of The Count of '
#                  'Monte Cristo, by Alexandre Dumas. Translated by Chapman and '
#                  'Hall',
#   'name': 'alexandre-dumas_the-count-of-monte-cristo_chapman-and-hall',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/alexandre-dumas_the-count-of-monte-cristo_chapman-and-hall'},
#  {'description': 'Epub source for the Standard Ebooks edition of The Three '
#                  'Musketeers, by Alexandre Dumas. Translated by William Robson',
#   'name': 'alexandre-dumas_the-three-musketeers_william-robson',
#   'owner': 'standardebooks',
#   'url': 'https://github.com/standardebooks/alexandre-dumas_the-three-musketeers_william-robson'}]
# 2024-04-12 09:51.05 [info     ] API Request                    [scrayping.github_api] method=GET module=github_api url=https://api.github.com/repos/standardebooks/a-a-milne_the-red-house-mystery/git/trees/master:src/epub/toc.xhtml
# 2024-04-12 09:51.05 [info     ] API Request                    [scrayping.github_api] method=GET module=github_api url=https://api.github.com/repos/standardebooks/a-a-milne_the-red-house-mystery/git/trees/master:src/epub/toc.xhtml
# Starting new HTTPS connection (1): api.github.com:443
# Starting new HTTPS connection (1): api.github.com:443
# https://api.github.com:443 "GET /repos/standardebooks/a-a-milne_the-red-house-mystery/git/trees/master:src/epub/toc.xhtml HTTP/1.1" 422 149
# https://api.github.com:443 "GET /repos/standardebooks/a-a-milne_the-red-house-mystery/git/trees/master:src/epub/toc.xhtml HTTP/1.1" 422 149
# 2024-04-12 09:51.05 [error    ] API Request Failed             [scrayping.github_api] module=github_api response_text={"message":"Invalid object requested. SHA must identify a commit or a tree.","documentation_url":"https://docs.github.com/rest/git/trees#get-a-tree"} status_code=422 url=https://api.github.com/repos/standardebooks/a-a-milne_the-red-house-mystery/git/trees/master:src/epub/toc.xhtml
# 2024-04-12 09:51.05 [error    ] API Request Failed             [scrayping.github_api] module=github_api response_text={"message":"Invalid object requested. SHA must identify a commit or a tree.","documentation_url":"https://docs.github.com/rest/git/trees#get-a-tree"} status_code=422 url=https://api.github.com/repos/standardebooks/a-a-milne_the-red-house-mystery/git/trees/master:src/epub/toc.xhtml
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 8
#       6 for repo in repos:
#       7     book_name = repo["name"]
# ----> 8     fetch_raw_toc_file(book_name, False, logger)
#       9     save_tree_info(book_name, False, logger)
#
# Cell In[5], line 122, in fetch_raw_toc_file(book_name, force, logger)
#     120 toc_file_url = build_toc_file_url(book_name)
#     121 toc_file_info = GithubApiManager().fetch_single_file_content_data(toc_file_url)
# --> 122 toc_file_info["content"] = base64.b64decode(toc_file_info["content"]).decode("utf-8")
#     124 save_chunk(toc_file_info, Path(f"{BOOK_DIR}/{book_name}/toc_file_info.json"), logger)
#     125 save_xhtml(toc_file_info["content"], Path(f"{BOOK_DIR}/{book_name}/toc.xhtml"), logger)
#
# KeyError: 'content'

# %%
https://api.github.com/repos/standardebooks/john-maynard-keynes_the-economic-consequences-of-the-peace/git/trees/master:src/epub/text\"
https://api.github.com/repos/standardebooks/a-a-milne_the-red-house-myster                           y/git/trees/master:src/epub/toc.xhtml
